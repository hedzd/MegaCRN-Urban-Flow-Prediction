# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import math
import numpy as np

import sys
import os
import shutil
import numpy as np
import pandas as pd
import time
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
from torchsummary import summary
import argparse
import logging

import pickle
import torch
import numpy as np
import pandas as pd

# %% [markdown]
# ## Process Input Data

# %%
import argparse
import numpy as np
import os
import pandas as pd

import ast


def generate_graph_seq2seq_io_data(
        df, x_offsets, y_offsets, add_time_in_day=True, add_day_in_week=False, scaler=None
):
    """
    Generate samples from
    :param df:
    :param x_offsets:
    :param y_offsets:
    :param add_time_in_day:
    :param add_day_in_week:
    :param scaler:
    :return:
    # x: (epoch_size, input_length, num_nodes, input_dim)
    # y: (epoch_size, output_length, num_nodes, output_dim)
    """

    num_samples, num_nodes = df.shape
    data = np.expand_dims(df.values, axis=-1)

    data_drop = data.copy()

    #NEW
    for i in range(len(data)):
      for j in range(len(data[i])):
        temp = str(data[i][j]).split("['(")[1].split(")']")[0]
        data[i][j] = int(temp.split(',')[0])
        data_drop[i][j] = int(temp.split(',')[1])

    data_list = [data, data_drop]

    #data_list = [data]

    if add_time_in_day:
        time_ind = (df.index.values - df.index.values.astype("datetime64[D]")) / np.timedelta64(1, "D")
        time_in_day = np.tile(time_ind, [1, num_nodes, 1]).transpose((2, 1, 0))
        data_list.append(time_in_day)
    if add_day_in_week:
        day_in_week = np.zeros(shape=(num_samples, num_nodes, 7))
        day_in_week[np.arange(num_samples), :, df.index.dayofweek] = 1
        data_list.append(day_in_week)

    data = np.concatenate(data_list, axis=-1)
    # epoch_len = num_samples + min(x_offsets) - max(y_offsets)
    x, y = [], []
    # t is the index of the last observation.
    min_t = abs(min(x_offsets))
    max_t = abs(num_samples - abs(max(y_offsets)))  # Exclusive
    for t in range(min_t, max_t):
        x_t = data[t + x_offsets, ...]
        y_t = data[t + y_offsets, ...]
        x.append(x_t)
        y.append(y_t)
    x = np.stack(x, axis=0)
    y = np.stack(y, axis=0)
    return x, y


def generate_train_val_test():
    df = pd.read_csv('01_21_new_pick_drop_nyc.csv')
    #NEW CODE_RF
    df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
    df.set_index('tpep_pickup_datetime', inplace=True)


    # 0 is the latest observed sample.
    x_offsets = np.sort(
        # np.concatenate(([-week_size + 1, -day_size + 1], np.arange(-11, 1, 1)))
        np.concatenate((np.arange(-6, 1, 1),))
    )
    # Predict the next one hour
    y_offsets = np.sort(np.arange(1, 4, 1))
    # x: (num_samples, input_length, num_nodes, input_dim)
    # y: (num_samples, output_length, num_nodes, output_dim)
    x, y = generate_graph_seq2seq_io_data(
        df,
        x_offsets=x_offsets,
        y_offsets=y_offsets,
        add_time_in_day=True,
        add_day_in_week=False,
    )

    print("x shape: ", x.shape, ", y shape: ", y.shape)
    # Write the data into npz file.
    # num_test = 6831, using the last 6831 examples as testing.
    # for the rest: 7/8 is used for training, and 1/8 is used for validation.
    num_samples = x.shape[0]
    num_test = round(num_samples * 0.2)
    num_train = round(num_samples * 0.7)
    num_val = num_samples - num_test - num_train

    # train
    x_train, y_train = x[:num_train], y[:num_train]
    #print(x_train[2])
    # val
    x_val, y_val = (
        x[num_train: num_train + num_val],
        y[num_train: num_train + num_val],
    )
    # test
    x_test, y_test = x[-num_test:], y[-num_test:]

    for cat in ["train", "val", "test"]:
        _x, _y = locals()["x_" + cat], locals()["y_" + cat]
        print(cat, "x: ", _x.shape, "y:", _y.shape)
        np.savez_compressed(
            os.path.join("%s.npz" % cat),
            x=_x,
            y=_y,
            x_offsets=x_offsets.reshape(list(x_offsets.shape) + [1]),
            y_offsets=y_offsets.reshape(list(y_offsets.shape) + [1]),
        )

# %%
generate_train_val_test()
# Out:
# x shape:  (239, 7, 258, 3) , y shape:  (239, 3, 258, 3)
# train x:  (167, 7, 258, 3) y: (167, 3, 258, 3)
# val x:  (24, 7, 258, 3) y: (24, 3, 258, 3)
# test x:  (48, 7, 258, 3) y: (48, 3, 258, 3)

# %% [markdown]
# ## Metrics

# %%
class DataLoader(object):
    def __init__(self, xs, ys, batch_size, pad_with_last_sample=True, shuffle=False):
        """

        :param xs:
        :param ys:
        :param batch_size:
        :param pad_with_last_sample: pad with the last sample to make number of samples divisible to batch_size.
        """
        self.batch_size = batch_size
        self.current_ind = 0
        if pad_with_last_sample:
            num_padding = (batch_size - (len(xs) % batch_size)) % batch_size
            x_padding = np.repeat(xs[-1:], num_padding, axis=0)
            y_padding = np.repeat(ys[-1:], num_padding, axis=0)
            xs = np.concatenate([xs, x_padding], axis=0)
            ys = np.concatenate([ys, y_padding], axis=0)
        self.size = len(xs)
        self.num_batch = int(self.size // self.batch_size)
        if shuffle:
            permutation = np.random.permutation(self.size)
            xs, ys = xs[permutation], ys[permutation]
        self.xs = xs
        self.ys = ys

    def get_iterator(self):
        self.current_ind = 0

        def _wrapper():
            while self.current_ind < self.num_batch:
                start_ind = self.batch_size * self.current_ind
                end_ind = min(self.size, self.batch_size * (self.current_ind + 1))
                x_i = self.xs[start_ind: end_ind, ...]
                y_i = self.ys[start_ind: end_ind, ...]
                yield (x_i, y_i)
                self.current_ind += 1

        return _wrapper()

class StandardScaler():
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def transform(self, data):
        return (data - self.mean) / self.std

    def inverse_transform(self, data):
        return (data * self.std) + self.mean

def getTimestamp(data):
    num_samples, num_nodes = data.shape
    time_ind = (data.index.values - data.index.values.astype("datetime64[D]")) / np.timedelta64(1, "D")
    time_in_day = np.tile(time_ind, [num_nodes,1]).transpose((1, 0))
    return time_in_day

def getDayTimestamp(data):
    # 288 timeslots each day for dataset has 5 minutes time interval.
    df = pd.DataFrame({'timestamp':data.index.values})
    df['weekdaytime'] = df['timestamp'].dt.weekday * 288 + (df['timestamp'].dt.hour * 60 + df['timestamp'].dt.minute)//5
    df['weekdaytime'] = df['weekdaytime'] / df['weekdaytime'].max()
    num_samples, num_nodes = data.shape
    time_ind = df['weekdaytime'].values
    time_ind_node = np.tile(time_ind, [num_nodes,1]).transpose((1, 0))
    return time_ind_node

def getDayTimestamp_(start, end, freq, num_nodes):
    # 288 timeslots each day for dataset has 5 minutes time interval.
    df = pd.DataFrame({'timestamp':pd.date_range(start=start, end=end, freq=freq)})
    df['weekdaytime'] = df['timestamp'].dt.weekday * 288 + (df['timestamp'].dt.hour * 60 + df['timestamp'].dt.minute)//5
    df['weekdaytime'] = df['weekdaytime'] / df['weekdaytime'].max()
    time_ind = df['weekdaytime'].values
    time_ind_node = np.tile(time_ind, [num_nodes, 1]).transpose((1, 0))
    return time_ind_node

def masked_mse(preds, labels, null_val=1e-3):
    if np.isnan(null_val):
        mask = ~torch.isnan(labels)
    else:
        mask = (labels > null_val)
    mask = mask.float()
    mask /= torch.mean((mask))
    mask = torch.where(torch.isnan(mask), torch.zeros_like(mask), mask)
    loss = (preds-labels)**2
    loss = loss * mask
    loss = torch.where(torch.isnan(loss), torch.zeros_like(loss), loss)
    return torch.mean(loss)

def masked_rmse(preds, labels, null_val=1e-3):
    return torch.sqrt(masked_mse(preds=preds, labels=labels, null_val=null_val))


def masked_mae(preds, labels, null_val=1e-3):
    if np.isnan(null_val):
        mask = ~torch.isnan(labels)
    else:
        mask = (labels > null_val)
    mask = mask.float()
    mask /=  torch.mean((mask))
    mask = torch.where(torch.isnan(mask), torch.zeros_like(mask), mask)
    loss = torch.abs(preds-labels)
    loss = loss * mask
    loss = torch.where(torch.isnan(loss), torch.zeros_like(loss), loss)
    return torch.mean(loss)


def masked_mape(preds, labels, null_val=1e-3):
    if np.isnan(null_val):
        mask = ~torch.isnan(labels)
    else:
        mask = (labels > null_val)
    mask = mask.float()
    mask /=  torch.mean((mask))
    mask = torch.where(torch.isnan(mask), torch.zeros_like(mask), mask)
    loss = torch.abs(preds-labels)/labels
    loss = loss * mask
    loss = torch.where(torch.isnan(loss), torch.zeros_like(loss), loss)
    return torch.mean(loss)

# DCRNN
def masked_mae_loss(y_pred, y_true):
    mask = (y_true != 0).float()
    mask /= mask.mean()
    loss = torch.abs(y_pred - y_true)
    loss = loss * mask
    # trick for nans: https://discuss.pytorch.org/t/how-to-set-nan-in-tensor-to-0/3918/3
    loss[loss != loss] = 0
    return loss.mean()

def masked_mape_loss(y_pred, y_true):
    mask = (y_true != 0).float()
    mask /= mask.mean()
    loss = torch.abs(torch.div(y_true - y_pred, y_true))
    loss = loss * mask
    # trick for nans: https://discuss.pytorch.org/t/how-to-set-nan-in-tensor-to-0/3918/3
    loss[loss != loss] = 0
    return loss.mean()

def masked_rmse_loss(y_pred, y_true):
    mask = (y_true != 0).float()
    mask /= mask.mean()
    loss = torch.pow(y_true - y_pred, 2)
    loss = loss * mask
    # trick for nans: https://discuss.pytorch.org/t/how-to-set-nan-in-tensor-to-0/3918/3
    loss[loss != loss] = 0
    return torch.sqrt(loss.mean())

def masked_mse_loss(y_pred, y_true):
    mask = (y_true != 0).float()
    mask /= mask.mean()
    loss = torch.pow(y_true - y_pred, 2)
    loss = loss * mask
    # trick for nans: https://discuss.pytorch.org/t/how-to-set-nan-in-tensor-to-0/3918/3
    loss[loss != loss] = 0
    return loss.mean()

def load_pickle(pickle_file):
    try:
        with open(pickle_file, 'rb') as f:
            pickle_data = pickle.load(f)
    except UnicodeDecodeError as e:
        with open(pickle_file, 'rb') as f:
            pickle_data = pickle.load(f, encoding='latin1')
    except Exception as e:
        print('Unable to load data ', pickle_file, ':', e)
        raise
    return pickle_data

def print_params(model):
    # print trainable params
    param_count = 0
    print('Trainable parameter list:')
    for name, param in model.named_parameters():
        if param.requires_grad:
            print(name, param.shape, param.numel())
            param_count += param.numel()
    print(f'\n In total: {param_count} trainable parameters. \n')
    return

# %% [markdown]
# ## MegaCRN

# %%
class AGCN(nn.Module):
    def __init__(self, dim_in, dim_out, cheb_k):
        super(AGCN, self).__init__()
        self.cheb_k = cheb_k
        self.weights = nn.Parameter(torch.FloatTensor(2*cheb_k*dim_in, dim_out)) # 2 is the length of support
        self.bias = nn.Parameter(torch.FloatTensor(dim_out))
        nn.init.xavier_normal_(self.weights)
        nn.init.constant_(self.bias, val=0)

    def forward(self, x, supports):
        x_g = []
        support_set = []
        for support in supports:
            support_ks = [torch.eye(support.shape[0]).to(support.device), support]
            for k in range(2, self.cheb_k):
                support_ks.append(torch.matmul(2 * support, support_ks[-1]) - support_ks[-2])
            support_set.extend(support_ks)
        for support in support_set:
            x_g.append(torch.einsum("nm,bmc->bnc", support, x))
        x_g = torch.cat(x_g, dim=-1) # B, N, 2 * cheb_k * dim_in
        x_gconv = torch.einsum('bni,io->bno', x_g, self.weights) + self.bias  # b, N, dim_out
        return x_gconv

class AGCRNCell(nn.Module):
    def __init__(self, node_num, dim_in, dim_out, cheb_k):
        super(AGCRNCell, self).__init__()
        self.node_num = node_num
        self.hidden_dim = dim_out
        self.gate = AGCN(dim_in+self.hidden_dim, 2*dim_out, cheb_k)
        self.update = AGCN(dim_in+self.hidden_dim, dim_out, cheb_k)

    def forward(self, x, state, supports):
        #x: B, num_nodes, input_dim
        #state: B, num_nodes, hidden_dim
        #print(x, state)
        state = state.to(x.device)
        input_and_state = torch.cat((x, state), dim=-1)
        z_r = torch.sigmoid(self.gate(input_and_state, supports))
        z, r = torch.split(z_r, self.hidden_dim, dim=-1)
        candidate = torch.cat((x, z*state), dim=-1)
        hc = torch.tanh(self.update(candidate, supports))
        h = r*state + (1-r)*hc
        return h

    def init_hidden_state(self, batch_size):
        return torch.zeros(batch_size, self.node_num, self.hidden_dim)

class ADCRNN_Encoder(nn.Module):
    def __init__(self, node_num, dim_in, dim_out, cheb_k, num_layers):
        super(ADCRNN_Encoder, self).__init__()
        assert num_layers >= 1, 'At least one DCRNN layer in the Encoder.'
        self.node_num = node_num
        self.input_dim = dim_in
        self.num_layers = num_layers
        self.dcrnn_cells = nn.ModuleList()
        self.dcrnn_cells.append(AGCRNCell(node_num, dim_in, dim_out, cheb_k))
        for _ in range(1, num_layers):
            self.dcrnn_cells.append(AGCRNCell(node_num, dim_out, dim_out, cheb_k))

    def forward(self, x, init_state, supports):
        #shape of x: (B, T, N, D), shape of init_state: (num_layers, B, N, hidden_dim)
        #print(x.shape)
        #print(x.shape[2], self.node_num, x.shape[3], self.input_dim)
        assert x.shape[2] == self.node_num and x.shape[3] == self.input_dim
        seq_length = x.shape[1]
        current_inputs = x
        output_hidden = []
        for i in range(self.num_layers):
            state = init_state[i]
            inner_states = []
            for t in range(seq_length):
                state = self.dcrnn_cells[i](current_inputs[:, t, :, :], state, supports)
                inner_states.append(state)
            output_hidden.append(state)
            current_inputs = torch.stack(inner_states, dim=1)
        #current_inputs: the outputs of last layer: (B, T, N, hidden_dim)
        #last_state: (B, N, hidden_dim)
        #output_hidden: the last state for each layer: (num_layers, B, N, hidden_dim)
        #return current_inputs, torch.stack(output_hidden, dim=0)
        return current_inputs, output_hidden

    def init_hidden(self, batch_size):
        init_states = []
        for i in range(self.num_layers):
            init_states.append(self.dcrnn_cells[i].init_hidden_state(batch_size))
        return init_states

class ADCRNN_Decoder(nn.Module):
    def __init__(self, node_num, dim_in, dim_out, cheb_k, num_layers):
        super(ADCRNN_Decoder, self).__init__()
        assert num_layers >= 1, 'At least one DCRNN layer in the Decoder.'
        self.node_num = node_num
        self.input_dim = dim_in
        self.num_layers = num_layers
        self.dcrnn_cells = nn.ModuleList()
        self.dcrnn_cells.append(AGCRNCell(node_num, dim_in, dim_out, cheb_k))
        for _ in range(1, num_layers):
            self.dcrnn_cells.append(AGCRNCell(node_num, dim_out, dim_out, cheb_k))

    def forward(self, xt, init_state, supports):
        # xt: (B, N, D)
        # init_state: (num_layers, B, N, hidden_dim)
        assert xt.shape[1] == self.node_num and xt.shape[2] == self.input_dim
        current_inputs = xt
        output_hidden = []
        for i in range(self.num_layers):
            state = self.dcrnn_cells[i](current_inputs, init_state[i], supports)
            output_hidden.append(state)
            current_inputs = state
        return current_inputs, output_hidden


class MegaCRN(nn.Module):
    def __init__(self, num_nodes, input_dim, output_dim, horizon, rnn_units, num_layers=1, cheb_k=3,
                 ycov_dim=1, mem_num=20, mem_dim=64, cl_decay_steps=2000, use_curriculum_learning=True):
        super(MegaCRN, self).__init__()
        self.num_nodes = num_nodes
        self.input_dim = input_dim
        self.rnn_units = rnn_units
        self.output_dim = output_dim
        self.horizon = horizon
        self.num_layers = num_layers
        self.cheb_k = cheb_k
        self.ycov_dim = ycov_dim
        self.cl_decay_steps = cl_decay_steps
        self.use_curriculum_learning = use_curriculum_learning

        # memory
        self.mem_num = mem_num
        self.mem_dim = mem_dim
        self.memory = self.construct_memory()

        # encoder
        self.encoder = ADCRNN_Encoder(self.num_nodes, self.input_dim, self.rnn_units, self.cheb_k, self.num_layers)

        # deocoder
        self.decoder_dim = self.rnn_units + self.mem_dim
        self.decoder = ADCRNN_Decoder(self.num_nodes, self.output_dim + self.ycov_dim, self.decoder_dim, self.cheb_k, self.num_layers)

        # output
        self.proj = nn.Sequential(nn.Linear(self.decoder_dim, self.output_dim, bias=True))

    def compute_sampling_threshold(self, batches_seen):
        return self.cl_decay_steps / (self.cl_decay_steps + np.exp(batches_seen / self.cl_decay_steps))

    def construct_memory(self):
        memory_dict = nn.ParameterDict()
        memory_dict['Memory'] = nn.Parameter(torch.randn(self.mem_num, self.mem_dim), requires_grad=True)     # (M, d)
        memory_dict['Wq'] = nn.Parameter(torch.randn(self.rnn_units, self.mem_dim), requires_grad=True)    # project to query
        memory_dict['We1'] = nn.Parameter(torch.randn(self.num_nodes, self.mem_num), requires_grad=True) # project memory to embedding
        memory_dict['We2'] = nn.Parameter(torch.randn(self.num_nodes, self.mem_num), requires_grad=True) # project memory to embedding
        for param in memory_dict.values():
            nn.init.xavier_normal_(param)
        return memory_dict

    def query_memory(self, h_t:torch.Tensor):
        query = torch.matmul(h_t, self.memory['Wq'])     # (B, N, d)
        att_score = torch.softmax(torch.matmul(query, self.memory['Memory'].t()), dim=-1)         # alpha: (B, N, M)
        value = torch.matmul(att_score, self.memory['Memory'])     # (B, N, d)
        _, ind = torch.topk(att_score, k=2, dim=-1)
        pos = self.memory['Memory'][ind[:, :, 0]] # B, N, d
        neg = self.memory['Memory'][ind[:, :, 1]] # B, N, d
        return value, query, pos, neg

    def forward(self, x, y_cov, labels=None, batches_seen=None):
        node_embeddings1 = torch.matmul(self.memory['We1'], self.memory['Memory'])
        node_embeddings2 = torch.matmul(self.memory['We2'], self.memory['Memory'])
        g1 = F.softmax(F.relu(torch.mm(node_embeddings1, node_embeddings2.T)), dim=-1)
        g2 = F.softmax(F.relu(torch.mm(node_embeddings2, node_embeddings1.T)), dim=-1)
        supports = [g1, g2]
        init_state = self.encoder.init_hidden(x.shape[0])
        h_en, state_en = self.encoder(x, init_state, supports) # B, T, N, hidden
        h_t = h_en[:, -1, :, :] # B, N, hidden (last state)

        h_att, query, pos, neg = self.query_memory(h_t)
        h_t = torch.cat([h_t, h_att], dim=-1)

        ht_list = [h_t]*self.num_layers
        go = torch.zeros((x.shape[0], self.num_nodes, self.output_dim), device=x.device)
        out = []
        for t in range(self.horizon):
            h_de, ht_list = self.decoder(torch.cat([go, y_cov[:, t, ...]], dim=-1), ht_list, supports)
            go = self.proj(h_de)
            out.append(go)
            if self.training and self.use_curriculum_learning:
                c = np.random.uniform(0, 1)
                if c < self.compute_sampling_threshold(batches_seen):
                    go = labels[:, t, ...]
        output = torch.stack(out, dim=1)

        return output, h_att, query, pos, neg

def print_params(model):
    # print trainable params
    param_count = 0
    print('Trainable parameter list:')
    for name, param in model.named_parameters():
        if param.requires_grad:
            print(name, param.shape, param.numel())
            param_count += param.numel()
    print(f'In total: {param_count} trainable parameters. \n')
    return

# %% [markdown]
# ## Train

# %%
def print_model(model):
    param_count = 0
    logger.info('Trainable parameter list:')
    for name, param in model.named_parameters():
        if param.requires_grad:
            print(name, param.shape, param.numel())
            param_count += param.numel()
    logger.info(f'In total: {param_count} trainable parameters.')
    return

def get_model():
  #Changed horizon and size of x and y inputs (in first preprocessing)
    model = MegaCRN(num_nodes=258, input_dim=2, output_dim=2, horizon=3,
                    rnn_units=128, num_layers=1, mem_num=50, mem_dim=64,
                    cheb_k = 5, cl_decay_steps=2000, use_curriculum_learning=True).to(device)
    return model

def prepare_x_y(x, y):
    """
    :param x: shape (batch_size, seq_len, num_sensor, input_dim)
    :param y: shape (batch_size, horizon, num_sensor, input_dim)
    :return1: x shape (seq_len, batch_size, num_sensor, input_dim)
              y shape (horizon, batch_size, num_sensor, input_dim)
    :return2: x: shape (seq_len, batch_size, num_sensor * input_dim)
              y: shape (horizon, batch_size, num_sensor * output_dim)
    """
    x0 = x[..., :2]
    y0 = y[..., :2]
    y1 = y[..., 2:]

    """x0 = x[..., :1]
    y0 = y[..., :1]
    y1 = y[..., 1:]"""

    # Check and convert x0
    if x0.dtype == np.object_:
        x0 = x0.astype(np.float32)  # or choose an appropriate numeric dtype

    # Check and convert y0
    if y0.dtype == np.object_:
        y0 = y0.astype(np.float32)  # or choose an appropriate numeric dtype

    # Check and convert y1
    if y1.dtype == np.object_:
        y1 = y1.astype(np.float32)  # or choose an appropriate numeric dtype


    x0 = torch.from_numpy(x0).float()
    y0 = torch.from_numpy(y0).float()
    y1 = torch.from_numpy(y1).float()

    return x0.to(device), y0.to(device), y1.to(device) # x, y, y_cov

def evaluate(model, mode):
    with torch.no_grad():
        model = model.eval()
        data_iter =  data[f'{mode}_loader'].get_iterator()
        losses, ys_true, ys_pred = [], [], []
        for x, y in data_iter:
            x, y, ycov = prepare_x_y(x, y)
            output, h_att, query, pos, neg = model(x, ycov)
            y_pred = scaler.inverse_transform(output)
            y_true = scaler.inverse_transform(y)
            loss1 = masked_mae_loss(y_pred, y_true) # masked_mae_loss(y_pred, y_true)
            separate_loss = nn.TripletMarginLoss(margin=1.0)
            compact_loss = nn.MSELoss()
            loss2 = separate_loss(query, pos.detach(), neg.detach())
            loss3 = compact_loss(query, pos.detach())
            loss = loss1 + 0.01 * loss2 + 0.01 * loss3
            losses.append(loss.item())
            ys_true.append(y_true)
            ys_pred.append(y_pred)
        mean_loss = np.mean(losses)
        y_size = data[f'y_{mode}'].shape[0]
        ys_true, ys_pred = torch.cat(ys_true, dim=0)[:y_size], torch.cat(ys_pred, dim=0)[:y_size]

        if mode == 'test':
            ys_true, ys_pred = ys_true.permute(1, 0, 2, 3), ys_pred.permute(1, 0, 2, 3)
            mae = masked_mae_loss(ys_pred, ys_true).item()
            mape = masked_mape_loss(ys_pred, ys_true).item()
            rmse = masked_rmse_loss(ys_pred, ys_true).item()
            mae_1 = masked_mae_loss(ys_pred[0:1], ys_true[0:1]).item()
            mape_1 = masked_mape_loss(ys_pred[0:1], ys_true[0:1]).item()
            rmse_1 = masked_rmse_loss(ys_pred[0:1], ys_true[0:1]).item()
            """mae_3 = masked_mae_loss(ys_pred[2:3], ys_true[2:3]).item()
            mape_3 = masked_mape_loss(ys_pred[2:3], ys_true[2:3]).item()
            rmse_3 = masked_rmse_loss(ys_pred[2:3], ys_true[2:3]).item()"""
            """mae_6 = masked_mae_loss(ys_pred[5:6], ys_true[5:6]).item()
            mape_6 = masked_mape_loss(ys_pred[5:6], ys_true[5:6]).item()
            rmse_6 = masked_rmse_loss(ys_pred[5:6], ys_true[5:6]).item()
            mae_12 = masked_mae_loss(ys_pred[11:12], ys_true[11:12]).item()
            mape_12 = masked_mape_loss(ys_pred[11:12], ys_true[11:12]).item()
            rmse_12 = masked_rmse_loss(ys_pred[11:12], ys_true[11:12]).item()"""
            logger.info('Horizon overall: mae: {:.4f}, mape: {:.4f}, rmse: {:.4f}'.format(mae, mape, rmse))
            logger.info('Horizon 5mins: mae: {:.4f}, mape: {:.4f}, rmse: {:.4f}'.format(mae_1, mape_1, rmse_1))
            #logger.info('Horizon 15mins: mae: {:.4f}, mape: {:.4f}, rmse: {:.4f}'.format(mae_3, mape_3, rmse_3))
            #logger.info('Horizon 30mins: mae: {:.4f}, mape: {:.4f}, rmse: {:.4f}'.format(mae_6, mape_6, rmse_6))
            #logger.info('Horizon 60mins: mae: {:.4f}, mape: {:.4f}, rmse: {:.4f}'.format(mae_12, mape_12, rmse_12))
            ys_true, ys_pred = ys_true.permute(1, 0, 2, 3), ys_pred.permute(1, 0, 2, 3)

        return mean_loss, ys_true, ys_pred

def traintest_model():
    model = get_model()
    print_model(model)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01, eps=0.001)
    lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[50,100], gamma=0.1)
    min_val_loss = float('inf')
    wait = 0
    batches_seen = 0
    for epoch_num in range(200):
        start_time = time.time()
        model = model.train()
        data_iter = data['train_loader'].get_iterator()
        losses = []
        for x, y in data_iter:
            optimizer.zero_grad()
            x, y, ycov = prepare_x_y(x, y)
            output, h_att, query, pos, neg = model(x, ycov, y, batches_seen)
            y_pred = scaler.inverse_transform(output)
            y_true = scaler.inverse_transform(y)
            loss1 = masked_mae_loss(y_pred, y_true)
            separate_loss = nn.TripletMarginLoss(margin=1.0)
            compact_loss = nn.MSELoss()
            loss2 = separate_loss(query, pos.detach(), neg.detach())
            loss3 = compact_loss(query, pos.detach())
            loss = loss1 + 0.01 * loss2 + 0.01 * loss3
            losses.append(loss.item())
            batches_seen += 1
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
            optimizer.step()
        train_loss = np.mean(losses)
        lr_scheduler.step()
        val_loss, _, _ = evaluate(model, 'val')
        end_time2 = time.time()
        message = 'Epoch [{}/{}] ({}) train_loss: {:.4f}, val_loss: {:.4f}, lr: {:.6f}, {:.1f}s'.format(epoch_num + 1,
                   500, batches_seen, train_loss, val_loss, optimizer.param_groups[0]['lr'], (end_time2 - start_time))
        logger.info(message)
        test_loss, _, _ = evaluate(model, 'test')

        if val_loss < min_val_loss:
            wait = 0
            min_val_loss = val_loss
            torch.save(model.state_dict(), modelpt_path)
        elif val_loss >= min_val_loss:
            wait += 1
            if wait == 40:
                logger.info('Early stopping at epoch: %d' % epoch_num)
                break

    logger.info('=' * 35 + 'Best model performance' + '=' * 35)
    model = get_model()
    model.load_state_dict(torch.load(modelpt_path))
    test_loss, predictions, _ = evaluate(model, 'test')
    print(predictions)

# %%
model_name = 'MegaCRN'
timestring = time.strftime('%Y%m%d%H%M%S', time.localtime())
logging_path = f'{model_name}_{timestring}_logging.txt'
score_path = f'{model_name}_{timestring}_scores.txt'
epochlog_path = f'{model_name}_{timestring}_epochlog.txt'
modelpt_path = f'{model_name}_{timestring}.pt'


logger = logging.getLogger(__name__)
logger.setLevel(level = logging.INFO)
class MyFormatter(logging.Formatter):
    def format(self, record):
        spliter = ' '
        record.msg = str(record.msg) + spliter + spliter.join(map(str, record.args))
        record.args = tuple() # set empty to args
        return super().format(record)
formatter = MyFormatter()
handler = logging.FileHandler(logging_path, mode='a')
handler.setLevel(logging.INFO)
handler.setFormatter(formatter)
console = logging.StreamHandler()
console.setLevel(logging.INFO)
console.setFormatter(formatter)
logger.addHandler(handler)
logger.addHandler(console)

logger.info('model', model_name)

device = "cuda" if torch.cuda.is_available() else "cpu"
# Please comment the following three lines for running experiments multiple times.
np.random.seed(0)
torch.manual_seed(0)
# Out:
# model MegaCRN
# model MegaCRN
# model MegaCRN
# INFO:__main__:model MegaCRN

# %%
data = {}
for category in ['train', 'test', 'val']:
    print(category)
    cat_data = np.load(os.path.join(category + '.npz'), allow_pickle=True)
    data['x_' + category] = cat_data['x']
    data['y_' + category] = cat_data['y']
    print(category)
scaler = StandardScaler(mean=data['x_train'][..., 0].mean(), std=data['x_train'][..., 0].std())
for category in ['train', 'val', 'test']:
    data['x_' + category][..., 0] = scaler.transform(data['x_' + category][..., 0])
    data['y_' + category][..., 0] = scaler.transform(data['y_' + category][..., 0])
    #New
    data['x_' + category][..., 1] = scaler.transform(data['x_' + category][..., 1])
    data['y_' + category][..., 1] = scaler.transform(data['y_' + category][..., 1])
data['train_loader'] = DataLoader(data['x_train'], data['y_train'], 64, shuffle=True)
data['val_loader'] = DataLoader(data['x_val'], data['y_val'], 64, shuffle=False)
data['test_loader'] = DataLoader(data['x_test'], data['y_test'], 64, shuffle=False)

def main():
    logger.info('training and testing started', time.ctime())
    logger.info('train xs.shape, ys.shape', data['x_train'].shape, data['y_train'].shape)
    logger.info('val xs.shape, ys.shape', data['x_val'].shape, data['y_val'].shape)
    logger.info('test xs.shape, ys.shape', data['x_test'].shape, data['y_test'].shape)
    traintest_model()
    logger.info('training and testing ended', time.ctime())
# Out:
# train
# train
# test
# test
# val
# val

# %%
main()
# Out:
# training and testing started Thu Dec 21 18:00:04 2023
# training and testing started Thu Dec 21 18:00:04 2023
# training and testing started Thu Dec 21 18:00:04 2023
# INFO:__main__:training and testing started Thu Dec 21 18:00:04 2023
# train xs.shape, ys.shape (167, 7, 258, 3) (167, 3, 258, 3)
# train xs.shape, ys.shape (167, 7, 258, 3) (167, 3, 258, 3)
# train xs.shape, ys.shape (167, 7, 258, 3) (167, 3, 258, 3)
# INFO:__main__:train xs.shape, ys.shape (167, 7, 258, 3) (167, 3, 258, 3)
# val xs.shape, ys.shape (24, 7, 258, 3) (24, 3, 258, 3)
# val xs.shape, ys.shape (24, 7, 258, 3) (24, 3, 258, 3)
# val xs.shape, ys.shape (24, 7, 258, 3) (24, 3, 258, 3)
# INFO:__main__:val xs.shape, ys.shape (24, 7, 258, 3) (24, 3, 258, 3)
# test xs.shape, ys.shape (48, 7, 258, 3) (48, 3, 258, 3)
# test xs.shape, ys.shape (48, 7, 258, 3) (48, 3, 258, 3)
# test xs.shape, ys.shape (48, 7, 258, 3) (48, 3, 258, 3)
# INFO:__main__:test xs.shape, ys.shape (48, 7, 258, 3) (48, 3, 258, 3)
# Trainable parameter list:
# Trainable parameter list:
# Trainable parameter list:
# INFO:__main__:Trainable parameter list:
# In total: 1660938 trainable parameters.
# In total: 1660938 trainable parameters.
# In total: 1660938 trainable parameters.
# INFO:__main__:In total: 1660938 trainable parameters.
# memory.Memory torch.Size([50, 64]) 3200
# memory.Wq torch.Size([128, 64]) 8192
# memory.We1 torch.Size([258, 50]) 12900
# memory.We2 torch.Size([258, 50]) 12900
# encoder.dcrnn_cells.0.gate.weights torch.Size([1300, 256]) 332800
# encoder.dcrnn_cells.0.gate.bias torch.Size([256]) 256
# encoder.dcrnn_cells.0.update.weights torch.Size([1300, 128]) 166400
# encoder.dcrnn_cells.0.update.bias torch.Size([128]) 128
# decoder.dcrnn_cells.0.gate.weights torch.Size([1950, 384]) 748800
# decoder.dcrnn_cells.0.gate.bias torch.Size([384]) 384
# decoder.dcrnn_cells.0.update.weights torch.Size([1950, 192]) 374400
# decoder.dcrnn_cells.0.update.bias torch.Size([192]) 192
# proj.0.weight torch.Size([2, 192]) 384
# proj.0.bias torch.Size([2]) 2
# Epoch [1/500] (3) train_loss: 39.0692, val_loss: 44.0909, lr: 0.010000, 2.1s
# Epoch [1/500] (3) train_loss: 39.0692, val_loss: 44.0909, lr: 0.010000, 2.1s
# Epoch [1/500] (3) train_loss: 39.0692, val_loss: 44.0909, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [1/500] (3) train_loss: 39.0692, val_loss: 44.0909, lr: 0.010000, 2.1s
# Horizon overall: mae: 47.7068, mape: 9.9976, rmse: 86.4697
# Horizon overall: mae: 47.7068, mape: 9.9976, rmse: 86.4697
# Horizon overall: mae: 47.7068, mape: 9.9976, rmse: 86.4697
# INFO:__main__:Horizon overall: mae: 47.7068, mape: 9.9976, rmse: 86.4697
# Horizon 5mins: mae: 46.8284, mape: 9.3061, rmse: 84.6806
# Horizon 5mins: mae: 46.8284, mape: 9.3061, rmse: 84.6806
# Horizon 5mins: mae: 46.8284, mape: 9.3061, rmse: 84.6806
# INFO:__main__:Horizon 5mins: mae: 46.8284, mape: 9.3061, rmse: 84.6806
# Epoch [2/500] (6) train_loss: 32.2473, val_loss: 38.8848, lr: 0.010000, 2.0s
# Epoch [2/500] (6) train_loss: 32.2473, val_loss: 38.8848, lr: 0.010000, 2.0s
# Epoch [2/500] (6) train_loss: 32.2473, val_loss: 38.8848, lr: 0.010000, 2.0s
# INFO:__main__:Epoch [2/500] (6) train_loss: 32.2473, val_loss: 38.8848, lr: 0.010000, 2.0s
# Horizon overall: mae: 44.4666, mape: 11.5367, rmse: 73.1509
# Horizon overall: mae: 44.4666, mape: 11.5367, rmse: 73.1509
# Horizon overall: mae: 44.4666, mape: 11.5367, rmse: 73.1509
# INFO:__main__:Horizon overall: mae: 44.4666, mape: 11.5367, rmse: 73.1509
# Horizon 5mins: mae: 44.1430, mape: 11.2389, rmse: 73.1620
# Horizon 5mins: mae: 44.1430, mape: 11.2389, rmse: 73.1620
# Horizon 5mins: mae: 44.1430, mape: 11.2389, rmse: 73.1620
# INFO:__main__:Horizon 5mins: mae: 44.1430, mape: 11.2389, rmse: 73.1620
# Epoch [3/500] (9) train_loss: 31.3497, val_loss: 24.3502, lr: 0.010000, 2.0s
# Epoch [3/500] (9) train_loss: 31.3497, val_loss: 24.3502, lr: 0.010000, 2.0s
# Epoch [3/500] (9) train_loss: 31.3497, val_loss: 24.3502, lr: 0.010000, 2.0s
# INFO:__main__:Epoch [3/500] (9) train_loss: 31.3497, val_loss: 24.3502, lr: 0.010000, 2.0s
# Horizon overall: mae: 28.8768, mape: 4.0643, rmse: 63.3674
# Horizon overall: mae: 28.8768, mape: 4.0643, rmse: 63.3674
# Horizon overall: mae: 28.8768, mape: 4.0643, rmse: 63.3674
# INFO:__main__:Horizon overall: mae: 28.8768, mape: 4.0643, rmse: 63.3674
# Horizon 5mins: mae: 27.2392, mape: 3.1216, rmse: 63.8708
# Horizon 5mins: mae: 27.2392, mape: 3.1216, rmse: 63.8708
# Horizon 5mins: mae: 27.2392, mape: 3.1216, rmse: 63.8708
# INFO:__main__:Horizon 5mins: mae: 27.2392, mape: 3.1216, rmse: 63.8708
# Epoch [4/500] (12) train_loss: 23.2090, val_loss: 22.2983, lr: 0.010000, 2.0s
# Epoch [4/500] (12) train_loss: 23.2090, val_loss: 22.2983, lr: 0.010000, 2.0s
# Epoch [4/500] (12) train_loss: 23.2090, val_loss: 22.2983, lr: 0.010000, 2.0s
# INFO:__main__:Epoch [4/500] (12) train_loss: 23.2090, val_loss: 22.2983, lr: 0.010000, 2.0s
# Horizon overall: mae: 23.1097, mape: 3.6535, rmse: 53.4944
# Horizon overall: mae: 23.1097, mape: 3.6535, rmse: 53.4944
# Horizon overall: mae: 23.1097, mape: 3.6535, rmse: 53.4944
# INFO:__main__:Horizon overall: mae: 23.1097, mape: 3.6535, rmse: 53.4944
# Horizon 5mins: mae: 24.6951, mape: 4.1189, rmse: 55.4514
# Horizon 5mins: mae: 24.6951, mape: 4.1189, rmse: 55.4514
# Horizon 5mins: mae: 24.6951, mape: 4.1189, rmse: 55.4514
# INFO:__main__:Horizon 5mins: mae: 24.6951, mape: 4.1189, rmse: 55.4514
# Epoch [5/500] (15) train_loss: 18.1826, val_loss: 17.7331, lr: 0.010000, 2.1s
# Epoch [5/500] (15) train_loss: 18.1826, val_loss: 17.7331, lr: 0.010000, 2.1s
# Epoch [5/500] (15) train_loss: 18.1826, val_loss: 17.7331, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [5/500] (15) train_loss: 18.1826, val_loss: 17.7331, lr: 0.010000, 2.1s
# Horizon overall: mae: 17.9754, mape: 2.3839, rmse: 47.8180
# Horizon overall: mae: 17.9754, mape: 2.3839, rmse: 47.8180
# Horizon overall: mae: 17.9754, mape: 2.3839, rmse: 47.8180
# INFO:__main__:Horizon overall: mae: 17.9754, mape: 2.3839, rmse: 47.8180
# Horizon 5mins: mae: 15.7019, mape: 2.1976, rmse: 41.5481
# Horizon 5mins: mae: 15.7019, mape: 2.1976, rmse: 41.5481
# Horizon 5mins: mae: 15.7019, mape: 2.1976, rmse: 41.5481
# INFO:__main__:Horizon 5mins: mae: 15.7019, mape: 2.1976, rmse: 41.5481
# Epoch [6/500] (18) train_loss: 14.6674, val_loss: 15.6210, lr: 0.010000, 2.1s
# Epoch [6/500] (18) train_loss: 14.6674, val_loss: 15.6210, lr: 0.010000, 2.1s
# Epoch [6/500] (18) train_loss: 14.6674, val_loss: 15.6210, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [6/500] (18) train_loss: 14.6674, val_loss: 15.6210, lr: 0.010000, 2.1s
# Horizon overall: mae: 17.1008, mape: 2.6511, rmse: 42.4840
# Horizon overall: mae: 17.1008, mape: 2.6511, rmse: 42.4840
# Horizon overall: mae: 17.1008, mape: 2.6511, rmse: 42.4840
# INFO:__main__:Horizon overall: mae: 17.1008, mape: 2.6511, rmse: 42.4840
# Horizon 5mins: mae: 15.7089, mape: 2.4493, rmse: 37.9954
# Horizon 5mins: mae: 15.7089, mape: 2.4493, rmse: 37.9954
# Horizon 5mins: mae: 15.7089, mape: 2.4493, rmse: 37.9954
# INFO:__main__:Horizon 5mins: mae: 15.7089, mape: 2.4493, rmse: 37.9954
# Epoch [7/500] (21) train_loss: 13.7718, val_loss: 16.5369, lr: 0.010000, 2.1s
# Epoch [7/500] (21) train_loss: 13.7718, val_loss: 16.5369, lr: 0.010000, 2.1s
# Epoch [7/500] (21) train_loss: 13.7718, val_loss: 16.5369, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [7/500] (21) train_loss: 13.7718, val_loss: 16.5369, lr: 0.010000, 2.1s
# Horizon overall: mae: 15.9343, mape: 2.1733, rmse: 37.8952
# Horizon overall: mae: 15.9343, mape: 2.1733, rmse: 37.8952
# Horizon overall: mae: 15.9343, mape: 2.1733, rmse: 37.8952
# INFO:__main__:Horizon overall: mae: 15.9343, mape: 2.1733, rmse: 37.8952
# Horizon 5mins: mae: 14.1180, mape: 2.2112, rmse: 33.7998
# Horizon 5mins: mae: 14.1180, mape: 2.2112, rmse: 33.7998
# Horizon 5mins: mae: 14.1180, mape: 2.2112, rmse: 33.7998
# INFO:__main__:Horizon 5mins: mae: 14.1180, mape: 2.2112, rmse: 33.7998
# Epoch [8/500] (24) train_loss: 12.7919, val_loss: 13.7258, lr: 0.010000, 2.1s
# Epoch [8/500] (24) train_loss: 12.7919, val_loss: 13.7258, lr: 0.010000, 2.1s
# Epoch [8/500] (24) train_loss: 12.7919, val_loss: 13.7258, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [8/500] (24) train_loss: 12.7919, val_loss: 13.7258, lr: 0.010000, 2.1s
# Horizon overall: mae: 14.0077, mape: 1.5454, rmse: 36.1624
# Horizon overall: mae: 14.0077, mape: 1.5454, rmse: 36.1624
# Horizon overall: mae: 14.0077, mape: 1.5454, rmse: 36.1624
# INFO:__main__:Horizon overall: mae: 14.0077, mape: 1.5454, rmse: 36.1624
# Horizon 5mins: mae: 11.5781, mape: 1.2142, rmse: 32.5760
# Horizon 5mins: mae: 11.5781, mape: 1.2142, rmse: 32.5760
# Horizon 5mins: mae: 11.5781, mape: 1.2142, rmse: 32.5760
# INFO:__main__:Horizon 5mins: mae: 11.5781, mape: 1.2142, rmse: 32.5760
# Epoch [9/500] (27) train_loss: 12.0309, val_loss: 11.7668, lr: 0.010000, 2.1s
# Epoch [9/500] (27) train_loss: 12.0309, val_loss: 11.7668, lr: 0.010000, 2.1s
# Epoch [9/500] (27) train_loss: 12.0309, val_loss: 11.7668, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [9/500] (27) train_loss: 12.0309, val_loss: 11.7668, lr: 0.010000, 2.1s
# Horizon overall: mae: 12.1143, mape: 1.0330, rmse: 35.1718
# Horizon overall: mae: 12.1143, mape: 1.0330, rmse: 35.1718
# Horizon overall: mae: 12.1143, mape: 1.0330, rmse: 35.1718
# INFO:__main__:Horizon overall: mae: 12.1143, mape: 1.0330, rmse: 35.1718
# Horizon 5mins: mae: 10.9000, mape: 1.0572, rmse: 30.9072
# Horizon 5mins: mae: 10.9000, mape: 1.0572, rmse: 30.9072
# Horizon 5mins: mae: 10.9000, mape: 1.0572, rmse: 30.9072
# INFO:__main__:Horizon 5mins: mae: 10.9000, mape: 1.0572, rmse: 30.9072
# Epoch [10/500] (30) train_loss: 12.3754, val_loss: 14.4692, lr: 0.010000, 2.1s
# Epoch [10/500] (30) train_loss: 12.3754, val_loss: 14.4692, lr: 0.010000, 2.1s
# Epoch [10/500] (30) train_loss: 12.3754, val_loss: 14.4692, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [10/500] (30) train_loss: 12.3754, val_loss: 14.4692, lr: 0.010000, 2.1s
# Horizon overall: mae: 14.3412, mape: 1.1563, rmse: 38.9340
# Horizon overall: mae: 14.3412, mape: 1.1563, rmse: 38.9340
# Horizon overall: mae: 14.3412, mape: 1.1563, rmse: 38.9340
# INFO:__main__:Horizon overall: mae: 14.3412, mape: 1.1563, rmse: 38.9340
# Horizon 5mins: mae: 12.2467, mape: 1.1227, rmse: 33.9005
# Horizon 5mins: mae: 12.2467, mape: 1.1227, rmse: 33.9005
# Horizon 5mins: mae: 12.2467, mape: 1.1227, rmse: 33.9005
# INFO:__main__:Horizon 5mins: mae: 12.2467, mape: 1.1227, rmse: 33.9005
# Epoch [11/500] (33) train_loss: 11.7880, val_loss: 13.0913, lr: 0.010000, 2.1s
# Epoch [11/500] (33) train_loss: 11.7880, val_loss: 13.0913, lr: 0.010000, 2.1s
# Epoch [11/500] (33) train_loss: 11.7880, val_loss: 13.0913, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [11/500] (33) train_loss: 11.7880, val_loss: 13.0913, lr: 0.010000, 2.1s
# Horizon overall: mae: 13.5338, mape: 1.3733, rmse: 35.0887
# Horizon overall: mae: 13.5338, mape: 1.3733, rmse: 35.0887
# Horizon overall: mae: 13.5338, mape: 1.3733, rmse: 35.0887
# INFO:__main__:Horizon overall: mae: 13.5338, mape: 1.3733, rmse: 35.0887
# Horizon 5mins: mae: 12.0361, mape: 1.2031, rmse: 30.9651
# Horizon 5mins: mae: 12.0361, mape: 1.2031, rmse: 30.9651
# Horizon 5mins: mae: 12.0361, mape: 1.2031, rmse: 30.9651
# INFO:__main__:Horizon 5mins: mae: 12.0361, mape: 1.2031, rmse: 30.9651
# Epoch [12/500] (36) train_loss: 10.4963, val_loss: 16.0374, lr: 0.010000, 2.1s
# Epoch [12/500] (36) train_loss: 10.4963, val_loss: 16.0374, lr: 0.010000, 2.1s
# Epoch [12/500] (36) train_loss: 10.4963, val_loss: 16.0374, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [12/500] (36) train_loss: 10.4963, val_loss: 16.0374, lr: 0.010000, 2.1s
# Horizon overall: mae: 12.5950, mape: 1.4837, rmse: 35.0562
# Horizon overall: mae: 12.5950, mape: 1.4837, rmse: 35.0562
# Horizon overall: mae: 12.5950, mape: 1.4837, rmse: 35.0562
# INFO:__main__:Horizon overall: mae: 12.5950, mape: 1.4837, rmse: 35.0562
# Horizon 5mins: mae: 11.3426, mape: 1.4546, rmse: 31.2113
# Horizon 5mins: mae: 11.3426, mape: 1.4546, rmse: 31.2113
# Horizon 5mins: mae: 11.3426, mape: 1.4546, rmse: 31.2113
# INFO:__main__:Horizon 5mins: mae: 11.3426, mape: 1.4546, rmse: 31.2113
# Epoch [13/500] (39) train_loss: 10.4125, val_loss: 11.7607, lr: 0.010000, 2.1s
# Epoch [13/500] (39) train_loss: 10.4125, val_loss: 11.7607, lr: 0.010000, 2.1s
# Epoch [13/500] (39) train_loss: 10.4125, val_loss: 11.7607, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [13/500] (39) train_loss: 10.4125, val_loss: 11.7607, lr: 0.010000, 2.1s
# Horizon overall: mae: 12.4697, mape: 1.9964, rmse: 31.1831
# Horizon overall: mae: 12.4697, mape: 1.9964, rmse: 31.1831
# Horizon overall: mae: 12.4697, mape: 1.9964, rmse: 31.1831
# INFO:__main__:Horizon overall: mae: 12.4697, mape: 1.9964, rmse: 31.1831
# Horizon 5mins: mae: 10.6806, mape: 1.6002, rmse: 27.6021
# Horizon 5mins: mae: 10.6806, mape: 1.6002, rmse: 27.6021
# Horizon 5mins: mae: 10.6806, mape: 1.6002, rmse: 27.6021
# INFO:__main__:Horizon 5mins: mae: 10.6806, mape: 1.6002, rmse: 27.6021
# Epoch [14/500] (42) train_loss: 10.5841, val_loss: 12.2928, lr: 0.010000, 2.1s
# Epoch [14/500] (42) train_loss: 10.5841, val_loss: 12.2928, lr: 0.010000, 2.1s
# Epoch [14/500] (42) train_loss: 10.5841, val_loss: 12.2928, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [14/500] (42) train_loss: 10.5841, val_loss: 12.2928, lr: 0.010000, 2.1s
# Horizon overall: mae: 12.0967, mape: 1.4722, rmse: 31.1435
# Horizon overall: mae: 12.0967, mape: 1.4722, rmse: 31.1435
# Horizon overall: mae: 12.0967, mape: 1.4722, rmse: 31.1435
# INFO:__main__:Horizon overall: mae: 12.0967, mape: 1.4722, rmse: 31.1435
# Horizon 5mins: mae: 9.9083, mape: 1.0238, rmse: 27.5217
# Horizon 5mins: mae: 9.9083, mape: 1.0238, rmse: 27.5217
# Horizon 5mins: mae: 9.9083, mape: 1.0238, rmse: 27.5217
# INFO:__main__:Horizon 5mins: mae: 9.9083, mape: 1.0238, rmse: 27.5217
# Epoch [15/500] (45) train_loss: 9.7833, val_loss: 11.9800, lr: 0.010000, 2.1s
# Epoch [15/500] (45) train_loss: 9.7833, val_loss: 11.9800, lr: 0.010000, 2.1s
# Epoch [15/500] (45) train_loss: 9.7833, val_loss: 11.9800, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [15/500] (45) train_loss: 9.7833, val_loss: 11.9800, lr: 0.010000, 2.1s
# Horizon overall: mae: 11.0302, mape: 1.1503, rmse: 29.6385
# Horizon overall: mae: 11.0302, mape: 1.1503, rmse: 29.6385
# Horizon overall: mae: 11.0302, mape: 1.1503, rmse: 29.6385
# INFO:__main__:Horizon overall: mae: 11.0302, mape: 1.1503, rmse: 29.6385
# Horizon 5mins: mae: 9.5461, mape: 0.9035, rmse: 26.5182
# Horizon 5mins: mae: 9.5461, mape: 0.9035, rmse: 26.5182
# Horizon 5mins: mae: 9.5461, mape: 0.9035, rmse: 26.5182
# INFO:__main__:Horizon 5mins: mae: 9.5461, mape: 0.9035, rmse: 26.5182
# Epoch [16/500] (48) train_loss: 9.5385, val_loss: 13.4423, lr: 0.010000, 2.1s
# Epoch [16/500] (48) train_loss: 9.5385, val_loss: 13.4423, lr: 0.010000, 2.1s
# Epoch [16/500] (48) train_loss: 9.5385, val_loss: 13.4423, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [16/500] (48) train_loss: 9.5385, val_loss: 13.4423, lr: 0.010000, 2.1s
# Horizon overall: mae: 11.4240, mape: 1.9500, rmse: 30.4134
# Horizon overall: mae: 11.4240, mape: 1.9500, rmse: 30.4134
# Horizon overall: mae: 11.4240, mape: 1.9500, rmse: 30.4134
# INFO:__main__:Horizon overall: mae: 11.4240, mape: 1.9500, rmse: 30.4134
# Horizon 5mins: mae: 10.5832, mape: 1.9088, rmse: 27.3744
# Horizon 5mins: mae: 10.5832, mape: 1.9088, rmse: 27.3744
# Horizon 5mins: mae: 10.5832, mape: 1.9088, rmse: 27.3744
# INFO:__main__:Horizon 5mins: mae: 10.5832, mape: 1.9088, rmse: 27.3744
# Epoch [17/500] (51) train_loss: 9.5628, val_loss: 13.8519, lr: 0.010000, 2.2s
# Epoch [17/500] (51) train_loss: 9.5628, val_loss: 13.8519, lr: 0.010000, 2.2s
# Epoch [17/500] (51) train_loss: 9.5628, val_loss: 13.8519, lr: 0.010000, 2.2s
# INFO:__main__:Epoch [17/500] (51) train_loss: 9.5628, val_loss: 13.8519, lr: 0.010000, 2.2s
# Horizon overall: mae: 12.2261, mape: 1.4516, rmse: 31.4213
# Horizon overall: mae: 12.2261, mape: 1.4516, rmse: 31.4213
# Horizon overall: mae: 12.2261, mape: 1.4516, rmse: 31.4213
# INFO:__main__:Horizon overall: mae: 12.2261, mape: 1.4516, rmse: 31.4213
# Horizon 5mins: mae: 10.9417, mape: 1.2464, rmse: 26.9599
# Horizon 5mins: mae: 10.9417, mape: 1.2464, rmse: 26.9599
# Horizon 5mins: mae: 10.9417, mape: 1.2464, rmse: 26.9599
# INFO:__main__:Horizon 5mins: mae: 10.9417, mape: 1.2464, rmse: 26.9599
# Epoch [18/500] (54) train_loss: 9.3711, val_loss: 11.6469, lr: 0.010000, 2.1s
# Epoch [18/500] (54) train_loss: 9.3711, val_loss: 11.6469, lr: 0.010000, 2.1s
# Epoch [18/500] (54) train_loss: 9.3711, val_loss: 11.6469, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [18/500] (54) train_loss: 9.3711, val_loss: 11.6469, lr: 0.010000, 2.1s
# Horizon overall: mae: 11.7743, mape: 1.8036, rmse: 31.5864
# Horizon overall: mae: 11.7743, mape: 1.8036, rmse: 31.5864
# Horizon overall: mae: 11.7743, mape: 1.8036, rmse: 31.5864
# INFO:__main__:Horizon overall: mae: 11.7743, mape: 1.8036, rmse: 31.5864
# Horizon 5mins: mae: 9.4079, mape: 1.1952, rmse: 26.4975
# Horizon 5mins: mae: 9.4079, mape: 1.1952, rmse: 26.4975
# Horizon 5mins: mae: 9.4079, mape: 1.1952, rmse: 26.4975
# INFO:__main__:Horizon 5mins: mae: 9.4079, mape: 1.1952, rmse: 26.4975
# Epoch [19/500] (57) train_loss: 9.1254, val_loss: 10.5537, lr: 0.010000, 2.1s
# Epoch [19/500] (57) train_loss: 9.1254, val_loss: 10.5537, lr: 0.010000, 2.1s
# Epoch [19/500] (57) train_loss: 9.1254, val_loss: 10.5537, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [19/500] (57) train_loss: 9.1254, val_loss: 10.5537, lr: 0.010000, 2.1s
# Horizon overall: mae: 9.9577, mape: 0.9915, rmse: 27.3656
# Horizon overall: mae: 9.9577, mape: 0.9915, rmse: 27.3656
# Horizon overall: mae: 9.9577, mape: 0.9915, rmse: 27.3656
# INFO:__main__:Horizon overall: mae: 9.9577, mape: 0.9915, rmse: 27.3656
# Horizon 5mins: mae: 9.0470, mape: 1.0764, rmse: 24.6511
# Horizon 5mins: mae: 9.0470, mape: 1.0764, rmse: 24.6511
# Horizon 5mins: mae: 9.0470, mape: 1.0764, rmse: 24.6511
# INFO:__main__:Horizon 5mins: mae: 9.0470, mape: 1.0764, rmse: 24.6511
# Epoch [20/500] (60) train_loss: 8.5634, val_loss: 11.1749, lr: 0.010000, 2.1s
# Epoch [20/500] (60) train_loss: 8.5634, val_loss: 11.1749, lr: 0.010000, 2.1s
# Epoch [20/500] (60) train_loss: 8.5634, val_loss: 11.1749, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [20/500] (60) train_loss: 8.5634, val_loss: 11.1749, lr: 0.010000, 2.1s
# Horizon overall: mae: 9.2287, mape: 0.7489, rmse: 27.1133
# Horizon overall: mae: 9.2287, mape: 0.7489, rmse: 27.1133
# Horizon overall: mae: 9.2287, mape: 0.7489, rmse: 27.1133
# INFO:__main__:Horizon overall: mae: 9.2287, mape: 0.7489, rmse: 27.1133
# Horizon 5mins: mae: 8.4223, mape: 0.6845, rmse: 25.0090
# Horizon 5mins: mae: 8.4223, mape: 0.6845, rmse: 25.0090
# Horizon 5mins: mae: 8.4223, mape: 0.6845, rmse: 25.0090
# INFO:__main__:Horizon 5mins: mae: 8.4223, mape: 0.6845, rmse: 25.0090
# Epoch [21/500] (63) train_loss: 8.1941, val_loss: 9.7932, lr: 0.010000, 2.1s
# Epoch [21/500] (63) train_loss: 8.1941, val_loss: 9.7932, lr: 0.010000, 2.1s
# Epoch [21/500] (63) train_loss: 8.1941, val_loss: 9.7932, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [21/500] (63) train_loss: 8.1941, val_loss: 9.7932, lr: 0.010000, 2.1s
# Horizon overall: mae: 9.4979, mape: 0.9504, rmse: 26.4160
# Horizon overall: mae: 9.4979, mape: 0.9504, rmse: 26.4160
# Horizon overall: mae: 9.4979, mape: 0.9504, rmse: 26.4160
# INFO:__main__:Horizon overall: mae: 9.4979, mape: 0.9504, rmse: 26.4160
# Horizon 5mins: mae: 8.7976, mape: 0.7646, rmse: 24.4229
# Horizon 5mins: mae: 8.7976, mape: 0.7646, rmse: 24.4229
# Horizon 5mins: mae: 8.7976, mape: 0.7646, rmse: 24.4229
# INFO:__main__:Horizon 5mins: mae: 8.7976, mape: 0.7646, rmse: 24.4229
# Epoch [22/500] (66) train_loss: 8.2183, val_loss: 11.1748, lr: 0.010000, 2.1s
# Epoch [22/500] (66) train_loss: 8.2183, val_loss: 11.1748, lr: 0.010000, 2.1s
# Epoch [22/500] (66) train_loss: 8.2183, val_loss: 11.1748, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [22/500] (66) train_loss: 8.2183, val_loss: 11.1748, lr: 0.010000, 2.1s
# Horizon overall: mae: 9.0271, mape: 0.8170, rmse: 26.2638
# Horizon overall: mae: 9.0271, mape: 0.8170, rmse: 26.2638
# Horizon overall: mae: 9.0271, mape: 0.8170, rmse: 26.2638
# INFO:__main__:Horizon overall: mae: 9.0271, mape: 0.8170, rmse: 26.2638
# Horizon 5mins: mae: 8.8121, mape: 0.9553, rmse: 24.4860
# Horizon 5mins: mae: 8.8121, mape: 0.9553, rmse: 24.4860
# Horizon 5mins: mae: 8.8121, mape: 0.9553, rmse: 24.4860
# INFO:__main__:Horizon 5mins: mae: 8.8121, mape: 0.9553, rmse: 24.4860
# Epoch [23/500] (69) train_loss: 7.8523, val_loss: 11.1473, lr: 0.010000, 2.1s
# Epoch [23/500] (69) train_loss: 7.8523, val_loss: 11.1473, lr: 0.010000, 2.1s
# Epoch [23/500] (69) train_loss: 7.8523, val_loss: 11.1473, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [23/500] (69) train_loss: 7.8523, val_loss: 11.1473, lr: 0.010000, 2.1s
# Horizon overall: mae: 9.3335, mape: 0.8658, rmse: 27.6801
# Horizon overall: mae: 9.3335, mape: 0.8658, rmse: 27.6801
# Horizon overall: mae: 9.3335, mape: 0.8658, rmse: 27.6801
# INFO:__main__:Horizon overall: mae: 9.3335, mape: 0.8658, rmse: 27.6801
# Horizon 5mins: mae: 8.4762, mape: 0.9059, rmse: 24.4062
# Horizon 5mins: mae: 8.4762, mape: 0.9059, rmse: 24.4062
# Horizon 5mins: mae: 8.4762, mape: 0.9059, rmse: 24.4062
# INFO:__main__:Horizon 5mins: mae: 8.4762, mape: 0.9059, rmse: 24.4062
# Epoch [24/500] (72) train_loss: 7.8007, val_loss: 10.9659, lr: 0.010000, 2.1s
# Epoch [24/500] (72) train_loss: 7.8007, val_loss: 10.9659, lr: 0.010000, 2.1s
# Epoch [24/500] (72) train_loss: 7.8007, val_loss: 10.9659, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [24/500] (72) train_loss: 7.8007, val_loss: 10.9659, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.7503, mape: 0.7918, rmse: 26.1699
# Horizon overall: mae: 8.7503, mape: 0.7918, rmse: 26.1699
# Horizon overall: mae: 8.7503, mape: 0.7918, rmse: 26.1699
# INFO:__main__:Horizon overall: mae: 8.7503, mape: 0.7918, rmse: 26.1699
# Horizon 5mins: mae: 8.0143, mape: 0.7677, rmse: 22.5645
# Horizon 5mins: mae: 8.0143, mape: 0.7677, rmse: 22.5645
# Horizon 5mins: mae: 8.0143, mape: 0.7677, rmse: 22.5645
# INFO:__main__:Horizon 5mins: mae: 8.0143, mape: 0.7677, rmse: 22.5645
# Epoch [25/500] (75) train_loss: 7.7211, val_loss: 10.4218, lr: 0.010000, 2.1s
# Epoch [25/500] (75) train_loss: 7.7211, val_loss: 10.4218, lr: 0.010000, 2.1s
# Epoch [25/500] (75) train_loss: 7.7211, val_loss: 10.4218, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [25/500] (75) train_loss: 7.7211, val_loss: 10.4218, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.6057, mape: 0.6060, rmse: 24.7600
# Horizon overall: mae: 8.6057, mape: 0.6060, rmse: 24.7600
# Horizon overall: mae: 8.6057, mape: 0.6060, rmse: 24.7600
# INFO:__main__:Horizon overall: mae: 8.6057, mape: 0.6060, rmse: 24.7600
# Horizon 5mins: mae: 8.0334, mape: 0.5393, rmse: 23.5852
# Horizon 5mins: mae: 8.0334, mape: 0.5393, rmse: 23.5852
# Horizon 5mins: mae: 8.0334, mape: 0.5393, rmse: 23.5852
# INFO:__main__:Horizon 5mins: mae: 8.0334, mape: 0.5393, rmse: 23.5852
# Epoch [26/500] (78) train_loss: 7.5153, val_loss: 9.1046, lr: 0.010000, 2.1s
# Epoch [26/500] (78) train_loss: 7.5153, val_loss: 9.1046, lr: 0.010000, 2.1s
# Epoch [26/500] (78) train_loss: 7.5153, val_loss: 9.1046, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [26/500] (78) train_loss: 7.5153, val_loss: 9.1046, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.8344, mape: 0.6784, rmse: 24.1571
# Horizon overall: mae: 8.8344, mape: 0.6784, rmse: 24.1571
# Horizon overall: mae: 8.8344, mape: 0.6784, rmse: 24.1571
# INFO:__main__:Horizon overall: mae: 8.8344, mape: 0.6784, rmse: 24.1571
# Horizon 5mins: mae: 8.2045, mape: 0.6254, rmse: 21.6920
# Horizon 5mins: mae: 8.2045, mape: 0.6254, rmse: 21.6920
# Horizon 5mins: mae: 8.2045, mape: 0.6254, rmse: 21.6920
# INFO:__main__:Horizon 5mins: mae: 8.2045, mape: 0.6254, rmse: 21.6920
# Epoch [27/500] (81) train_loss: 7.2272, val_loss: 10.0586, lr: 0.010000, 2.1s
# Epoch [27/500] (81) train_loss: 7.2272, val_loss: 10.0586, lr: 0.010000, 2.1s
# Epoch [27/500] (81) train_loss: 7.2272, val_loss: 10.0586, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [27/500] (81) train_loss: 7.2272, val_loss: 10.0586, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.5736, mape: 0.7168, rmse: 23.3093
# Horizon overall: mae: 8.5736, mape: 0.7168, rmse: 23.3093
# Horizon overall: mae: 8.5736, mape: 0.7168, rmse: 23.3093
# INFO:__main__:Horizon overall: mae: 8.5736, mape: 0.7168, rmse: 23.3093
# Horizon 5mins: mae: 8.1793, mape: 0.7336, rmse: 22.3522
# Horizon 5mins: mae: 8.1793, mape: 0.7336, rmse: 22.3522
# Horizon 5mins: mae: 8.1793, mape: 0.7336, rmse: 22.3522
# INFO:__main__:Horizon 5mins: mae: 8.1793, mape: 0.7336, rmse: 22.3522
# Epoch [28/500] (84) train_loss: 7.3848, val_loss: 9.6829, lr: 0.010000, 2.1s
# Epoch [28/500] (84) train_loss: 7.3848, val_loss: 9.6829, lr: 0.010000, 2.1s
# Epoch [28/500] (84) train_loss: 7.3848, val_loss: 9.6829, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [28/500] (84) train_loss: 7.3848, val_loss: 9.6829, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.9682, mape: 0.8124, rmse: 23.8535
# Horizon overall: mae: 8.9682, mape: 0.8124, rmse: 23.8535
# Horizon overall: mae: 8.9682, mape: 0.8124, rmse: 23.8535
# INFO:__main__:Horizon overall: mae: 8.9682, mape: 0.8124, rmse: 23.8535
# Horizon 5mins: mae: 8.3330, mape: 0.6550, rmse: 21.6827
# Horizon 5mins: mae: 8.3330, mape: 0.6550, rmse: 21.6827
# Horizon 5mins: mae: 8.3330, mape: 0.6550, rmse: 21.6827
# INFO:__main__:Horizon 5mins: mae: 8.3330, mape: 0.6550, rmse: 21.6827
# Epoch [29/500] (87) train_loss: 7.6220, val_loss: 10.2704, lr: 0.010000, 2.1s
# Epoch [29/500] (87) train_loss: 7.6220, val_loss: 10.2704, lr: 0.010000, 2.1s
# Epoch [29/500] (87) train_loss: 7.6220, val_loss: 10.2704, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [29/500] (87) train_loss: 7.6220, val_loss: 10.2704, lr: 0.010000, 2.1s
# Horizon overall: mae: 9.0543, mape: 0.7680, rmse: 25.6513
# Horizon overall: mae: 9.0543, mape: 0.7680, rmse: 25.6513
# Horizon overall: mae: 9.0543, mape: 0.7680, rmse: 25.6513
# INFO:__main__:Horizon overall: mae: 9.0543, mape: 0.7680, rmse: 25.6513
# Horizon 5mins: mae: 7.9080, mape: 0.7636, rmse: 21.5740
# Horizon 5mins: mae: 7.9080, mape: 0.7636, rmse: 21.5740
# Horizon 5mins: mae: 7.9080, mape: 0.7636, rmse: 21.5740
# INFO:__main__:Horizon 5mins: mae: 7.9080, mape: 0.7636, rmse: 21.5740
# Epoch [30/500] (90) train_loss: 7.7628, val_loss: 9.4596, lr: 0.010000, 2.1s
# Epoch [30/500] (90) train_loss: 7.7628, val_loss: 9.4596, lr: 0.010000, 2.1s
# Epoch [30/500] (90) train_loss: 7.7628, val_loss: 9.4596, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [30/500] (90) train_loss: 7.7628, val_loss: 9.4596, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.2410, mape: 0.7512, rmse: 22.2353
# Horizon overall: mae: 8.2410, mape: 0.7512, rmse: 22.2353
# Horizon overall: mae: 8.2410, mape: 0.7512, rmse: 22.2353
# INFO:__main__:Horizon overall: mae: 8.2410, mape: 0.7512, rmse: 22.2353
# Horizon 5mins: mae: 7.4870, mape: 0.7566, rmse: 20.0359
# Horizon 5mins: mae: 7.4870, mape: 0.7566, rmse: 20.0359
# Horizon 5mins: mae: 7.4870, mape: 0.7566, rmse: 20.0359
# INFO:__main__:Horizon 5mins: mae: 7.4870, mape: 0.7566, rmse: 20.0359
# Epoch [31/500] (93) train_loss: 7.3394, val_loss: 10.8159, lr: 0.010000, 2.1s
# Epoch [31/500] (93) train_loss: 7.3394, val_loss: 10.8159, lr: 0.010000, 2.1s
# Epoch [31/500] (93) train_loss: 7.3394, val_loss: 10.8159, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [31/500] (93) train_loss: 7.3394, val_loss: 10.8159, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.3599, mape: 0.7633, rmse: 22.5108
# Horizon overall: mae: 8.3599, mape: 0.7633, rmse: 22.5108
# Horizon overall: mae: 8.3599, mape: 0.7633, rmse: 22.5108
# INFO:__main__:Horizon overall: mae: 8.3599, mape: 0.7633, rmse: 22.5108
# Horizon 5mins: mae: 7.7340, mape: 0.7466, rmse: 20.0619
# Horizon 5mins: mae: 7.7340, mape: 0.7466, rmse: 20.0619
# Horizon 5mins: mae: 7.7340, mape: 0.7466, rmse: 20.0619
# INFO:__main__:Horizon 5mins: mae: 7.7340, mape: 0.7466, rmse: 20.0619
# Epoch [32/500] (96) train_loss: 7.3354, val_loss: 8.5888, lr: 0.010000, 2.1s
# Epoch [32/500] (96) train_loss: 7.3354, val_loss: 8.5888, lr: 0.010000, 2.1s
# Epoch [32/500] (96) train_loss: 7.3354, val_loss: 8.5888, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [32/500] (96) train_loss: 7.3354, val_loss: 8.5888, lr: 0.010000, 2.1s
# Horizon overall: mae: 7.9727, mape: 0.5889, rmse: 22.2187
# Horizon overall: mae: 7.9727, mape: 0.5889, rmse: 22.2187
# Horizon overall: mae: 7.9727, mape: 0.5889, rmse: 22.2187
# INFO:__main__:Horizon overall: mae: 7.9727, mape: 0.5889, rmse: 22.2187
# Horizon 5mins: mae: 7.1059, mape: 0.6285, rmse: 19.1199
# Horizon 5mins: mae: 7.1059, mape: 0.6285, rmse: 19.1199
# Horizon 5mins: mae: 7.1059, mape: 0.6285, rmse: 19.1199
# INFO:__main__:Horizon 5mins: mae: 7.1059, mape: 0.6285, rmse: 19.1199
# Epoch [33/500] (99) train_loss: 6.8697, val_loss: 10.0447, lr: 0.010000, 2.1s
# Epoch [33/500] (99) train_loss: 6.8697, val_loss: 10.0447, lr: 0.010000, 2.1s
# Epoch [33/500] (99) train_loss: 6.8697, val_loss: 10.0447, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [33/500] (99) train_loss: 6.8697, val_loss: 10.0447, lr: 0.010000, 2.1s
# Horizon overall: mae: 7.9555, mape: 0.6481, rmse: 20.9183
# Horizon overall: mae: 7.9555, mape: 0.6481, rmse: 20.9183
# Horizon overall: mae: 7.9555, mape: 0.6481, rmse: 20.9183
# INFO:__main__:Horizon overall: mae: 7.9555, mape: 0.6481, rmse: 20.9183
# Horizon 5mins: mae: 7.3264, mape: 0.5869, rmse: 19.4756
# Horizon 5mins: mae: 7.3264, mape: 0.5869, rmse: 19.4756
# Horizon 5mins: mae: 7.3264, mape: 0.5869, rmse: 19.4756
# INFO:__main__:Horizon 5mins: mae: 7.3264, mape: 0.5869, rmse: 19.4756
# Epoch [34/500] (102) train_loss: 6.9465, val_loss: 9.0344, lr: 0.010000, 2.1s
# Epoch [34/500] (102) train_loss: 6.9465, val_loss: 9.0344, lr: 0.010000, 2.1s
# Epoch [34/500] (102) train_loss: 6.9465, val_loss: 9.0344, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [34/500] (102) train_loss: 6.9465, val_loss: 9.0344, lr: 0.010000, 2.1s
# Horizon overall: mae: 7.9691, mape: 0.7486, rmse: 20.0849
# Horizon overall: mae: 7.9691, mape: 0.7486, rmse: 20.0849
# Horizon overall: mae: 7.9691, mape: 0.7486, rmse: 20.0849
# INFO:__main__:Horizon overall: mae: 7.9691, mape: 0.7486, rmse: 20.0849
# Horizon 5mins: mae: 7.3692, mape: 0.7011, rmse: 18.5585
# Horizon 5mins: mae: 7.3692, mape: 0.7011, rmse: 18.5585
# Horizon 5mins: mae: 7.3692, mape: 0.7011, rmse: 18.5585
# INFO:__main__:Horizon 5mins: mae: 7.3692, mape: 0.7011, rmse: 18.5585
# Epoch [35/500] (105) train_loss: 7.1237, val_loss: 9.3242, lr: 0.010000, 2.1s
# Epoch [35/500] (105) train_loss: 7.1237, val_loss: 9.3242, lr: 0.010000, 2.1s
# Epoch [35/500] (105) train_loss: 7.1237, val_loss: 9.3242, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [35/500] (105) train_loss: 7.1237, val_loss: 9.3242, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.4936, mape: 0.6291, rmse: 21.7735
# Horizon overall: mae: 8.4936, mape: 0.6291, rmse: 21.7735
# Horizon overall: mae: 8.4936, mape: 0.6291, rmse: 21.7735
# INFO:__main__:Horizon overall: mae: 8.4936, mape: 0.6291, rmse: 21.7735
# Horizon 5mins: mae: 6.7996, mape: 0.6050, rmse: 17.8445
# Horizon 5mins: mae: 6.7996, mape: 0.6050, rmse: 17.8445
# Horizon 5mins: mae: 6.7996, mape: 0.6050, rmse: 17.8445
# INFO:__main__:Horizon 5mins: mae: 6.7996, mape: 0.6050, rmse: 17.8445
# Epoch [36/500] (108) train_loss: 7.1428, val_loss: 8.6548, lr: 0.010000, 2.1s
# Epoch [36/500] (108) train_loss: 7.1428, val_loss: 8.6548, lr: 0.010000, 2.1s
# Epoch [36/500] (108) train_loss: 7.1428, val_loss: 8.6548, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [36/500] (108) train_loss: 7.1428, val_loss: 8.6548, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.2160, mape: 0.7206, rmse: 22.1414
# Horizon overall: mae: 8.2160, mape: 0.7206, rmse: 22.1414
# Horizon overall: mae: 8.2160, mape: 0.7206, rmse: 22.1414
# INFO:__main__:Horizon overall: mae: 8.2160, mape: 0.7206, rmse: 22.1414
# Horizon 5mins: mae: 6.9768, mape: 0.6716, rmse: 17.8972
# Horizon 5mins: mae: 6.9768, mape: 0.6716, rmse: 17.8972
# Horizon 5mins: mae: 6.9768, mape: 0.6716, rmse: 17.8972
# INFO:__main__:Horizon 5mins: mae: 6.9768, mape: 0.6716, rmse: 17.8972
# Epoch [37/500] (111) train_loss: 7.1128, val_loss: 9.7017, lr: 0.010000, 2.1s
# Epoch [37/500] (111) train_loss: 7.1128, val_loss: 9.7017, lr: 0.010000, 2.1s
# Epoch [37/500] (111) train_loss: 7.1128, val_loss: 9.7017, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [37/500] (111) train_loss: 7.1128, val_loss: 9.7017, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.0658, mape: 0.6510, rmse: 20.0733
# Horizon overall: mae: 8.0658, mape: 0.6510, rmse: 20.0733
# Horizon overall: mae: 8.0658, mape: 0.6510, rmse: 20.0733
# INFO:__main__:Horizon overall: mae: 8.0658, mape: 0.6510, rmse: 20.0733
# Horizon 5mins: mae: 7.1187, mape: 0.5162, rmse: 18.4987
# Horizon 5mins: mae: 7.1187, mape: 0.5162, rmse: 18.4987
# Horizon 5mins: mae: 7.1187, mape: 0.5162, rmse: 18.4987
# INFO:__main__:Horizon 5mins: mae: 7.1187, mape: 0.5162, rmse: 18.4987
# Epoch [38/500] (114) train_loss: 7.0593, val_loss: 8.4745, lr: 0.010000, 2.1s
# Epoch [38/500] (114) train_loss: 7.0593, val_loss: 8.4745, lr: 0.010000, 2.1s
# Epoch [38/500] (114) train_loss: 7.0593, val_loss: 8.4745, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [38/500] (114) train_loss: 7.0593, val_loss: 8.4745, lr: 0.010000, 2.1s
# Horizon overall: mae: 8.7100, mape: 0.8426, rmse: 21.6462
# Horizon overall: mae: 8.7100, mape: 0.8426, rmse: 21.6462
# Horizon overall: mae: 8.7100, mape: 0.8426, rmse: 21.6462
# INFO:__main__:Horizon overall: mae: 8.7100, mape: 0.8426, rmse: 21.6462
# Horizon 5mins: mae: 7.8478, mape: 0.6977, rmse: 19.3184
# Horizon 5mins: mae: 7.8478, mape: 0.6977, rmse: 19.3184
# Horizon 5mins: mae: 7.8478, mape: 0.6977, rmse: 19.3184
# INFO:__main__:Horizon 5mins: mae: 7.8478, mape: 0.6977, rmse: 19.3184
# Epoch [39/500] (117) train_loss: 6.6808, val_loss: 10.4620, lr: 0.010000, 2.1s
# Epoch [39/500] (117) train_loss: 6.6808, val_loss: 10.4620, lr: 0.010000, 2.1s
# Epoch [39/500] (117) train_loss: 6.6808, val_loss: 10.4620, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [39/500] (117) train_loss: 6.6808, val_loss: 10.4620, lr: 0.010000, 2.1s
# Horizon overall: mae: 7.5978, mape: 0.8601, rmse: 19.2598
# Horizon overall: mae: 7.5978, mape: 0.8601, rmse: 19.2598
# Horizon overall: mae: 7.5978, mape: 0.8601, rmse: 19.2598
# INFO:__main__:Horizon overall: mae: 7.5978, mape: 0.8601, rmse: 19.2598
# Horizon 5mins: mae: 7.2389, mape: 0.7278, rmse: 19.1385
# Horizon 5mins: mae: 7.2389, mape: 0.7278, rmse: 19.1385
# Horizon 5mins: mae: 7.2389, mape: 0.7278, rmse: 19.1385
# INFO:__main__:Horizon 5mins: mae: 7.2389, mape: 0.7278, rmse: 19.1385
# Epoch [40/500] (120) train_loss: 6.5235, val_loss: 8.2765, lr: 0.010000, 2.1s
# Epoch [40/500] (120) train_loss: 6.5235, val_loss: 8.2765, lr: 0.010000, 2.1s
# Epoch [40/500] (120) train_loss: 6.5235, val_loss: 8.2765, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [40/500] (120) train_loss: 6.5235, val_loss: 8.2765, lr: 0.010000, 2.1s
# Horizon overall: mae: 7.1443, mape: 0.5716, rmse: 18.3590
# Horizon overall: mae: 7.1443, mape: 0.5716, rmse: 18.3590
# Horizon overall: mae: 7.1443, mape: 0.5716, rmse: 18.3590
# INFO:__main__:Horizon overall: mae: 7.1443, mape: 0.5716, rmse: 18.3590
# Horizon 5mins: mae: 6.5714, mape: 0.5866, rmse: 16.6230
# Horizon 5mins: mae: 6.5714, mape: 0.5866, rmse: 16.6230
# Horizon 5mins: mae: 6.5714, mape: 0.5866, rmse: 16.6230
# INFO:__main__:Horizon 5mins: mae: 6.5714, mape: 0.5866, rmse: 16.6230
# Epoch [41/500] (123) train_loss: 6.3792, val_loss: 8.9290, lr: 0.010000, 2.1s
# Epoch [41/500] (123) train_loss: 6.3792, val_loss: 8.9290, lr: 0.010000, 2.1s
# Epoch [41/500] (123) train_loss: 6.3792, val_loss: 8.9290, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [41/500] (123) train_loss: 6.3792, val_loss: 8.9290, lr: 0.010000, 2.1s
# Horizon overall: mae: 7.4281, mape: 0.7354, rmse: 18.1387
# Horizon overall: mae: 7.4281, mape: 0.7354, rmse: 18.1387
# Horizon overall: mae: 7.4281, mape: 0.7354, rmse: 18.1387
# INFO:__main__:Horizon overall: mae: 7.4281, mape: 0.7354, rmse: 18.1387
# Horizon 5mins: mae: 6.9339, mape: 0.6117, rmse: 17.1873
# Horizon 5mins: mae: 6.9339, mape: 0.6117, rmse: 17.1873
# Horizon 5mins: mae: 6.9339, mape: 0.6117, rmse: 17.1873
# INFO:__main__:Horizon 5mins: mae: 6.9339, mape: 0.6117, rmse: 17.1873
# Epoch [42/500] (126) train_loss: 6.4040, val_loss: 8.0693, lr: 0.010000, 2.1s
# Epoch [42/500] (126) train_loss: 6.4040, val_loss: 8.0693, lr: 0.010000, 2.1s
# Epoch [42/500] (126) train_loss: 6.4040, val_loss: 8.0693, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [42/500] (126) train_loss: 6.4040, val_loss: 8.0693, lr: 0.010000, 2.1s
# Horizon overall: mae: 6.9668, mape: 0.6236, rmse: 18.0943
# Horizon overall: mae: 6.9668, mape: 0.6236, rmse: 18.0943
# Horizon overall: mae: 6.9668, mape: 0.6236, rmse: 18.0943
# INFO:__main__:Horizon overall: mae: 6.9668, mape: 0.6236, rmse: 18.0943
# Horizon 5mins: mae: 6.4715, mape: 0.6230, rmse: 16.8009
# Horizon 5mins: mae: 6.4715, mape: 0.6230, rmse: 16.8009
# Horizon 5mins: mae: 6.4715, mape: 0.6230, rmse: 16.8009
# INFO:__main__:Horizon 5mins: mae: 6.4715, mape: 0.6230, rmse: 16.8009
# Epoch [43/500] (129) train_loss: 6.3569, val_loss: 8.3223, lr: 0.010000, 2.1s
# Epoch [43/500] (129) train_loss: 6.3569, val_loss: 8.3223, lr: 0.010000, 2.1s
# Epoch [43/500] (129) train_loss: 6.3569, val_loss: 8.3223, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [43/500] (129) train_loss: 6.3569, val_loss: 8.3223, lr: 0.010000, 2.1s
# Horizon overall: mae: 7.4114, mape: 0.9698, rmse: 17.9658
# Horizon overall: mae: 7.4114, mape: 0.9698, rmse: 17.9658
# Horizon overall: mae: 7.4114, mape: 0.9698, rmse: 17.9658
# INFO:__main__:Horizon overall: mae: 7.4114, mape: 0.9698, rmse: 17.9658
# Horizon 5mins: mae: 6.9038, mape: 0.9263, rmse: 16.1429
# Horizon 5mins: mae: 6.9038, mape: 0.9263, rmse: 16.1429
# Horizon 5mins: mae: 6.9038, mape: 0.9263, rmse: 16.1429
# INFO:__main__:Horizon 5mins: mae: 6.9038, mape: 0.9263, rmse: 16.1429
# Epoch [44/500] (132) train_loss: 6.1261, val_loss: 8.1803, lr: 0.010000, 2.1s
# Epoch [44/500] (132) train_loss: 6.1261, val_loss: 8.1803, lr: 0.010000, 2.1s
# Epoch [44/500] (132) train_loss: 6.1261, val_loss: 8.1803, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [44/500] (132) train_loss: 6.1261, val_loss: 8.1803, lr: 0.010000, 2.1s
# Horizon overall: mae: 6.8561, mape: 0.5757, rmse: 17.0800
# Horizon overall: mae: 6.8561, mape: 0.5757, rmse: 17.0800
# Horizon overall: mae: 6.8561, mape: 0.5757, rmse: 17.0800
# INFO:__main__:Horizon overall: mae: 6.8561, mape: 0.5757, rmse: 17.0800
# Horizon 5mins: mae: 6.4309, mape: 0.5360, rmse: 16.0142
# Horizon 5mins: mae: 6.4309, mape: 0.5360, rmse: 16.0142
# Horizon 5mins: mae: 6.4309, mape: 0.5360, rmse: 16.0142
# INFO:__main__:Horizon 5mins: mae: 6.4309, mape: 0.5360, rmse: 16.0142
# Epoch [45/500] (135) train_loss: 6.0961, val_loss: 8.0678, lr: 0.010000, 2.1s
# Epoch [45/500] (135) train_loss: 6.0961, val_loss: 8.0678, lr: 0.010000, 2.1s
# Epoch [45/500] (135) train_loss: 6.0961, val_loss: 8.0678, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [45/500] (135) train_loss: 6.0961, val_loss: 8.0678, lr: 0.010000, 2.1s
# Horizon overall: mae: 7.1147, mape: 0.8001, rmse: 17.6576
# Horizon overall: mae: 7.1147, mape: 0.8001, rmse: 17.6576
# Horizon overall: mae: 7.1147, mape: 0.8001, rmse: 17.6576
# INFO:__main__:Horizon overall: mae: 7.1147, mape: 0.8001, rmse: 17.6576
# Horizon 5mins: mae: 6.6950, mape: 0.7116, rmse: 16.7629
# Horizon 5mins: mae: 6.6950, mape: 0.7116, rmse: 16.7629
# Horizon 5mins: mae: 6.6950, mape: 0.7116, rmse: 16.7629
# INFO:__main__:Horizon 5mins: mae: 6.6950, mape: 0.7116, rmse: 16.7629
# Epoch [46/500] (138) train_loss: 6.0677, val_loss: 7.5456, lr: 0.010000, 2.1s
# Epoch [46/500] (138) train_loss: 6.0677, val_loss: 7.5456, lr: 0.010000, 2.1s
# Epoch [46/500] (138) train_loss: 6.0677, val_loss: 7.5456, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [46/500] (138) train_loss: 6.0677, val_loss: 7.5456, lr: 0.010000, 2.1s
# Horizon overall: mae: 6.9340, mape: 0.8101, rmse: 17.1846
# Horizon overall: mae: 6.9340, mape: 0.8101, rmse: 17.1846
# Horizon overall: mae: 6.9340, mape: 0.8101, rmse: 17.1846
# INFO:__main__:Horizon overall: mae: 6.9340, mape: 0.8101, rmse: 17.1846
# Horizon 5mins: mae: 6.4854, mape: 0.7474, rmse: 15.7899
# Horizon 5mins: mae: 6.4854, mape: 0.7474, rmse: 15.7899
# Horizon 5mins: mae: 6.4854, mape: 0.7474, rmse: 15.7899
# INFO:__main__:Horizon 5mins: mae: 6.4854, mape: 0.7474, rmse: 15.7899
# Epoch [47/500] (141) train_loss: 5.7690, val_loss: 8.0799, lr: 0.010000, 2.1s
# Epoch [47/500] (141) train_loss: 5.7690, val_loss: 8.0799, lr: 0.010000, 2.1s
# Epoch [47/500] (141) train_loss: 5.7690, val_loss: 8.0799, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [47/500] (141) train_loss: 5.7690, val_loss: 8.0799, lr: 0.010000, 2.1s
# Horizon overall: mae: 6.6706, mape: 0.5444, rmse: 16.9110
# Horizon overall: mae: 6.6706, mape: 0.5444, rmse: 16.9110
# Horizon overall: mae: 6.6706, mape: 0.5444, rmse: 16.9110
# INFO:__main__:Horizon overall: mae: 6.6706, mape: 0.5444, rmse: 16.9110
# Horizon 5mins: mae: 6.2056, mape: 0.5707, rmse: 15.5763
# Horizon 5mins: mae: 6.2056, mape: 0.5707, rmse: 15.5763
# Horizon 5mins: mae: 6.2056, mape: 0.5707, rmse: 15.5763
# INFO:__main__:Horizon 5mins: mae: 6.2056, mape: 0.5707, rmse: 15.5763
# Epoch [48/500] (144) train_loss: 5.8384, val_loss: 7.9113, lr: 0.010000, 2.1s
# Epoch [48/500] (144) train_loss: 5.8384, val_loss: 7.9113, lr: 0.010000, 2.1s
# Epoch [48/500] (144) train_loss: 5.8384, val_loss: 7.9113, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [48/500] (144) train_loss: 5.8384, val_loss: 7.9113, lr: 0.010000, 2.1s
# Horizon overall: mae: 6.7306, mape: 0.6306, rmse: 16.9576
# Horizon overall: mae: 6.7306, mape: 0.6306, rmse: 16.9576
# Horizon overall: mae: 6.7306, mape: 0.6306, rmse: 16.9576
# INFO:__main__:Horizon overall: mae: 6.7306, mape: 0.6306, rmse: 16.9576
# Horizon 5mins: mae: 6.1865, mape: 0.5506, rmse: 15.3206
# Horizon 5mins: mae: 6.1865, mape: 0.5506, rmse: 15.3206
# Horizon 5mins: mae: 6.1865, mape: 0.5506, rmse: 15.3206
# INFO:__main__:Horizon 5mins: mae: 6.1865, mape: 0.5506, rmse: 15.3206
# Epoch [49/500] (147) train_loss: 5.6581, val_loss: 7.1763, lr: 0.010000, 2.1s
# Epoch [49/500] (147) train_loss: 5.6581, val_loss: 7.1763, lr: 0.010000, 2.1s
# Epoch [49/500] (147) train_loss: 5.6581, val_loss: 7.1763, lr: 0.010000, 2.1s
# INFO:__main__:Epoch [49/500] (147) train_loss: 5.6581, val_loss: 7.1763, lr: 0.010000, 2.1s
# Horizon overall: mae: 6.6041, mape: 0.6390, rmse: 16.1046
# Horizon overall: mae: 6.6041, mape: 0.6390, rmse: 16.1046
# Horizon overall: mae: 6.6041, mape: 0.6390, rmse: 16.1046
# INFO:__main__:Horizon overall: mae: 6.6041, mape: 0.6390, rmse: 16.1046
# Horizon 5mins: mae: 6.2226, mape: 0.6129, rmse: 14.9269
# Horizon 5mins: mae: 6.2226, mape: 0.6129, rmse: 14.9269
# Horizon 5mins: mae: 6.2226, mape: 0.6129, rmse: 14.9269
# INFO:__main__:Horizon 5mins: mae: 6.2226, mape: 0.6129, rmse: 14.9269
# Epoch [50/500] (150) train_loss: 5.7664, val_loss: 7.6095, lr: 0.001000, 2.1s
# Epoch [50/500] (150) train_loss: 5.7664, val_loss: 7.6095, lr: 0.001000, 2.1s
# Epoch [50/500] (150) train_loss: 5.7664, val_loss: 7.6095, lr: 0.001000, 2.1s
# INFO:__main__:Epoch [50/500] (150) train_loss: 5.7664, val_loss: 7.6095, lr: 0.001000, 2.1s
# Horizon overall: mae: 6.6999, mape: 0.6594, rmse: 16.6486
# Horizon overall: mae: 6.6999, mape: 0.6594, rmse: 16.6486
# Horizon overall: mae: 6.6999, mape: 0.6594, rmse: 16.6486
# INFO:__main__:Horizon overall: mae: 6.6999, mape: 0.6594, rmse: 16.6486
# Horizon 5mins: mae: 6.1936, mape: 0.5342, rmse: 15.2768
# Horizon 5mins: mae: 6.1936, mape: 0.5342, rmse: 15.2768
# Horizon 5mins: mae: 6.1936, mape: 0.5342, rmse: 15.2768
# INFO:__main__:Horizon 5mins: mae: 6.1936, mape: 0.5342, rmse: 15.2768
# Epoch [51/500] (153) train_loss: 5.5356, val_loss: 7.1779, lr: 0.001000, 2.1s
# Epoch [51/500] (153) train_loss: 5.5356, val_loss: 7.1779, lr: 0.001000, 2.1s
# Epoch [51/500] (153) train_loss: 5.5356, val_loss: 7.1779, lr: 0.001000, 2.1s
# INFO:__main__:Epoch [51/500] (153) train_loss: 5.5356, val_loss: 7.1779, lr: 0.001000, 2.1s
# Horizon overall: mae: 6.3214, mape: 0.5195, rmse: 15.9731
# Horizon overall: mae: 6.3214, mape: 0.5195, rmse: 15.9731
# Horizon overall: mae: 6.3214, mape: 0.5195, rmse: 15.9731
# INFO:__main__:Horizon overall: mae: 6.3214, mape: 0.5195, rmse: 15.9731
# Horizon 5mins: mae: 5.9982, mape: 0.4777, rmse: 14.7922
# Horizon 5mins: mae: 5.9982, mape: 0.4777, rmse: 14.7922
# Horizon 5mins: mae: 5.9982, mape: 0.4777, rmse: 14.7922
# INFO:__main__:Horizon 5mins: mae: 5.9982, mape: 0.4777, rmse: 14.7922
# Epoch [52/500] (156) train_loss: 5.2621, val_loss: 7.0767, lr: 0.001000, 2.1s
# Epoch [52/500] (156) train_loss: 5.2621, val_loss: 7.0767, lr: 0.001000, 2.1s
# Epoch [52/500] (156) train_loss: 5.2621, val_loss: 7.0767, lr: 0.001000, 2.1s
# INFO:__main__:Epoch [52/500] (156) train_loss: 5.2621, val_loss: 7.0767, lr: 0.001000, 2.1s
# Horizon overall: mae: 6.1612, mape: 0.5054, rmse: 15.7075
# Horizon overall: mae: 6.1612, mape: 0.5054, rmse: 15.7075
# Horizon overall: mae: 6.1612, mape: 0.5054, rmse: 15.7075
# INFO:__main__:Horizon overall: mae: 6.1612, mape: 0.5054, rmse: 15.7075
# Horizon 5mins: mae: 5.8844, mape: 0.5109, rmse: 14.5923
# Horizon 5mins: mae: 5.8844, mape: 0.5109, rmse: 14.5923
# Horizon 5mins: mae: 5.8844, mape: 0.5109, rmse: 14.5923
# INFO:__main__:Horizon 5mins: mae: 5.8844, mape: 0.5109, rmse: 14.5923
# Epoch [53/500] (159) train_loss: 5.2729, val_loss: 7.0066, lr: 0.001000, 2.1s
# Epoch [53/500] (159) train_loss: 5.2729, val_loss: 7.0066, lr: 0.001000, 2.1s
# Epoch [53/500] (159) train_loss: 5.2729, val_loss: 7.0066, lr: 0.001000, 2.1s
# INFO:__main__:Epoch [53/500] (159) train_loss: 5.2729, val_loss: 7.0066, lr: 0.001000, 2.1s
# Horizon overall: mae: 6.1500, mape: 0.5205, rmse: 15.5701
# Horizon overall: mae: 6.1500, mape: 0.5205, rmse: 15.5701
# Horizon overall: mae: 6.1500, mape: 0.5205, rmse: 15.5701
# INFO:__main__:Horizon overall: mae: 6.1500, mape: 0.5205, rmse: 15.5701
# Horizon 5mins: mae: 5.8658, mape: 0.5179, rmse: 14.3083
# Horizon 5mins: mae: 5.8658, mape: 0.5179, rmse: 14.3083
# Horizon 5mins: mae: 5.8658, mape: 0.5179, rmse: 14.3083
# INFO:__main__:Horizon 5mins: mae: 5.8658, mape: 0.5179, rmse: 14.3083
# ...
# INFO:__main__:Epoch [188/500] (564) train_loss: 4.0812, val_loss: 5.7821, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5688, mape: 0.4654, rmse: 13.5473
# Horizon overall: mae: 5.5688, mape: 0.4654, rmse: 13.5473
# Horizon overall: mae: 5.5688, mape: 0.4654, rmse: 13.5473
# INFO:__main__:Horizon overall: mae: 5.5688, mape: 0.4654, rmse: 13.5473
# Horizon 5mins: mae: 5.3189, mape: 0.4606, rmse: 12.2923
# Horizon 5mins: mae: 5.3189, mape: 0.4606, rmse: 12.2923
# Horizon 5mins: mae: 5.3189, mape: 0.4606, rmse: 12.2923
# INFO:__main__:Horizon 5mins: mae: 5.3189, mape: 0.4606, rmse: 12.2923
# Epoch [189/500] (567) train_loss: 4.0780, val_loss: 5.7764, lr: 0.000100, 2.1s
# Epoch [189/500] (567) train_loss: 4.0780, val_loss: 5.7764, lr: 0.000100, 2.1s
# Epoch [189/500] (567) train_loss: 4.0780, val_loss: 5.7764, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [189/500] (567) train_loss: 4.0780, val_loss: 5.7764, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5686, mape: 0.4645, rmse: 13.5555
# Horizon overall: mae: 5.5686, mape: 0.4645, rmse: 13.5555
# Horizon overall: mae: 5.5686, mape: 0.4645, rmse: 13.5555
# INFO:__main__:Horizon overall: mae: 5.5686, mape: 0.4645, rmse: 13.5555
# Horizon 5mins: mae: 5.3187, mape: 0.4602, rmse: 12.2901
# Horizon 5mins: mae: 5.3187, mape: 0.4602, rmse: 12.2901
# Horizon 5mins: mae: 5.3187, mape: 0.4602, rmse: 12.2901
# INFO:__main__:Horizon 5mins: mae: 5.3187, mape: 0.4602, rmse: 12.2901
# Epoch [190/500] (570) train_loss: 4.0768, val_loss: 5.7828, lr: 0.000100, 2.1s
# Epoch [190/500] (570) train_loss: 4.0768, val_loss: 5.7828, lr: 0.000100, 2.1s
# Epoch [190/500] (570) train_loss: 4.0768, val_loss: 5.7828, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [190/500] (570) train_loss: 4.0768, val_loss: 5.7828, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5729, mape: 0.4661, rmse: 13.5583
# Horizon overall: mae: 5.5729, mape: 0.4661, rmse: 13.5583
# Horizon overall: mae: 5.5729, mape: 0.4661, rmse: 13.5583
# INFO:__main__:Horizon overall: mae: 5.5729, mape: 0.4661, rmse: 13.5583
# Horizon 5mins: mae: 5.3199, mape: 0.4616, rmse: 12.2918
# Horizon 5mins: mae: 5.3199, mape: 0.4616, rmse: 12.2918
# Horizon 5mins: mae: 5.3199, mape: 0.4616, rmse: 12.2918
# INFO:__main__:Horizon 5mins: mae: 5.3199, mape: 0.4616, rmse: 12.2918
# Epoch [191/500] (573) train_loss: 4.0753, val_loss: 5.7840, lr: 0.000100, 2.1s
# Epoch [191/500] (573) train_loss: 4.0753, val_loss: 5.7840, lr: 0.000100, 2.1s
# Epoch [191/500] (573) train_loss: 4.0753, val_loss: 5.7840, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [191/500] (573) train_loss: 4.0753, val_loss: 5.7840, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5711, mape: 0.4650, rmse: 13.5543
# Horizon overall: mae: 5.5711, mape: 0.4650, rmse: 13.5543
# Horizon overall: mae: 5.5711, mape: 0.4650, rmse: 13.5543
# INFO:__main__:Horizon overall: mae: 5.5711, mape: 0.4650, rmse: 13.5543
# Horizon 5mins: mae: 5.3185, mape: 0.4609, rmse: 12.2857
# Horizon 5mins: mae: 5.3185, mape: 0.4609, rmse: 12.2857
# Horizon 5mins: mae: 5.3185, mape: 0.4609, rmse: 12.2857
# INFO:__main__:Horizon 5mins: mae: 5.3185, mape: 0.4609, rmse: 12.2857
# Epoch [192/500] (576) train_loss: 4.0736, val_loss: 5.7808, lr: 0.000100, 2.1s
# Epoch [192/500] (576) train_loss: 4.0736, val_loss: 5.7808, lr: 0.000100, 2.1s
# Epoch [192/500] (576) train_loss: 4.0736, val_loss: 5.7808, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [192/500] (576) train_loss: 4.0736, val_loss: 5.7808, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5710, mape: 0.4645, rmse: 13.5522
# Horizon overall: mae: 5.5710, mape: 0.4645, rmse: 13.5522
# Horizon overall: mae: 5.5710, mape: 0.4645, rmse: 13.5522
# INFO:__main__:Horizon overall: mae: 5.5710, mape: 0.4645, rmse: 13.5522
# Horizon 5mins: mae: 5.3169, mape: 0.4601, rmse: 12.2820
# Horizon 5mins: mae: 5.3169, mape: 0.4601, rmse: 12.2820
# Horizon 5mins: mae: 5.3169, mape: 0.4601, rmse: 12.2820
# INFO:__main__:Horizon 5mins: mae: 5.3169, mape: 0.4601, rmse: 12.2820
# Epoch [193/500] (579) train_loss: 4.0736, val_loss: 5.7732, lr: 0.000100, 2.1s
# Epoch [193/500] (579) train_loss: 4.0736, val_loss: 5.7732, lr: 0.000100, 2.1s
# Epoch [193/500] (579) train_loss: 4.0736, val_loss: 5.7732, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [193/500] (579) train_loss: 4.0736, val_loss: 5.7732, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5674, mape: 0.4656, rmse: 13.5414
# Horizon overall: mae: 5.5674, mape: 0.4656, rmse: 13.5414
# Horizon overall: mae: 5.5674, mape: 0.4656, rmse: 13.5414
# INFO:__main__:Horizon overall: mae: 5.5674, mape: 0.4656, rmse: 13.5414
# Horizon 5mins: mae: 5.3163, mape: 0.4609, rmse: 12.2794
# Horizon 5mins: mae: 5.3163, mape: 0.4609, rmse: 12.2794
# Horizon 5mins: mae: 5.3163, mape: 0.4609, rmse: 12.2794
# INFO:__main__:Horizon 5mins: mae: 5.3163, mape: 0.4609, rmse: 12.2794
# Epoch [194/500] (582) train_loss: 4.0727, val_loss: 5.7682, lr: 0.000100, 2.1s
# Epoch [194/500] (582) train_loss: 4.0727, val_loss: 5.7682, lr: 0.000100, 2.1s
# Epoch [194/500] (582) train_loss: 4.0727, val_loss: 5.7682, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [194/500] (582) train_loss: 4.0727, val_loss: 5.7682, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5616, mape: 0.4634, rmse: 13.5354
# Horizon overall: mae: 5.5616, mape: 0.4634, rmse: 13.5354
# Horizon overall: mae: 5.5616, mape: 0.4634, rmse: 13.5354
# INFO:__main__:Horizon overall: mae: 5.5616, mape: 0.4634, rmse: 13.5354
# Horizon 5mins: mae: 5.3168, mape: 0.4600, rmse: 12.2826
# Horizon 5mins: mae: 5.3168, mape: 0.4600, rmse: 12.2826
# Horizon 5mins: mae: 5.3168, mape: 0.4600, rmse: 12.2826
# INFO:__main__:Horizon 5mins: mae: 5.3168, mape: 0.4600, rmse: 12.2826
# Epoch [195/500] (585) train_loss: 4.0716, val_loss: 5.7692, lr: 0.000100, 2.1s
# Epoch [195/500] (585) train_loss: 4.0716, val_loss: 5.7692, lr: 0.000100, 2.1s
# Epoch [195/500] (585) train_loss: 4.0716, val_loss: 5.7692, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [195/500] (585) train_loss: 4.0716, val_loss: 5.7692, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5680, mape: 0.4648, rmse: 13.5471
# Horizon overall: mae: 5.5680, mape: 0.4648, rmse: 13.5471
# Horizon overall: mae: 5.5680, mape: 0.4648, rmse: 13.5471
# INFO:__main__:Horizon overall: mae: 5.5680, mape: 0.4648, rmse: 13.5471
# Horizon 5mins: mae: 5.3158, mape: 0.4604, rmse: 12.2805
# Horizon 5mins: mae: 5.3158, mape: 0.4604, rmse: 12.2805
# Horizon 5mins: mae: 5.3158, mape: 0.4604, rmse: 12.2805
# INFO:__main__:Horizon 5mins: mae: 5.3158, mape: 0.4604, rmse: 12.2805
# Epoch [196/500] (588) train_loss: 4.0723, val_loss: 5.7730, lr: 0.000100, 2.1s
# Epoch [196/500] (588) train_loss: 4.0723, val_loss: 5.7730, lr: 0.000100, 2.1s
# Epoch [196/500] (588) train_loss: 4.0723, val_loss: 5.7730, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [196/500] (588) train_loss: 4.0723, val_loss: 5.7730, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5683, mape: 0.4673, rmse: 13.5436
# Horizon overall: mae: 5.5683, mape: 0.4673, rmse: 13.5436
# Horizon overall: mae: 5.5683, mape: 0.4673, rmse: 13.5436
# INFO:__main__:Horizon overall: mae: 5.5683, mape: 0.4673, rmse: 13.5436
# Horizon 5mins: mae: 5.3156, mape: 0.4621, rmse: 12.2741
# Horizon 5mins: mae: 5.3156, mape: 0.4621, rmse: 12.2741
# Horizon 5mins: mae: 5.3156, mape: 0.4621, rmse: 12.2741
# INFO:__main__:Horizon 5mins: mae: 5.3156, mape: 0.4621, rmse: 12.2741
# Epoch [197/500] (591) train_loss: 4.0720, val_loss: 5.7609, lr: 0.000100, 2.1s
# Epoch [197/500] (591) train_loss: 4.0720, val_loss: 5.7609, lr: 0.000100, 2.1s
# Epoch [197/500] (591) train_loss: 4.0720, val_loss: 5.7609, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [197/500] (591) train_loss: 4.0720, val_loss: 5.7609, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5584, mape: 0.4617, rmse: 13.5210
# Horizon overall: mae: 5.5584, mape: 0.4617, rmse: 13.5210
# Horizon overall: mae: 5.5584, mape: 0.4617, rmse: 13.5210
# INFO:__main__:Horizon overall: mae: 5.5584, mape: 0.4617, rmse: 13.5210
# Horizon 5mins: mae: 5.3125, mape: 0.4587, rmse: 12.2684
# Horizon 5mins: mae: 5.3125, mape: 0.4587, rmse: 12.2684
# Horizon 5mins: mae: 5.3125, mape: 0.4587, rmse: 12.2684
# INFO:__main__:Horizon 5mins: mae: 5.3125, mape: 0.4587, rmse: 12.2684
# Epoch [198/500] (594) train_loss: 4.0708, val_loss: 5.7754, lr: 0.000100, 2.1s
# Epoch [198/500] (594) train_loss: 4.0708, val_loss: 5.7754, lr: 0.000100, 2.1s
# Epoch [198/500] (594) train_loss: 4.0708, val_loss: 5.7754, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [198/500] (594) train_loss: 4.0708, val_loss: 5.7754, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5710, mape: 0.4673, rmse: 13.5428
# Horizon overall: mae: 5.5710, mape: 0.4673, rmse: 13.5428
# Horizon overall: mae: 5.5710, mape: 0.4673, rmse: 13.5428
# INFO:__main__:Horizon overall: mae: 5.5710, mape: 0.4673, rmse: 13.5428
# Horizon 5mins: mae: 5.3186, mape: 0.4622, rmse: 12.2816
# Horizon 5mins: mae: 5.3186, mape: 0.4622, rmse: 12.2816
# Horizon 5mins: mae: 5.3186, mape: 0.4622, rmse: 12.2816
# INFO:__main__:Horizon 5mins: mae: 5.3186, mape: 0.4622, rmse: 12.2816
# Epoch [199/500] (597) train_loss: 4.0694, val_loss: 5.7565, lr: 0.000100, 2.1s
# Epoch [199/500] (597) train_loss: 4.0694, val_loss: 5.7565, lr: 0.000100, 2.1s
# Epoch [199/500] (597) train_loss: 4.0694, val_loss: 5.7565, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [199/500] (597) train_loss: 4.0694, val_loss: 5.7565, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5604, mape: 0.4621, rmse: 13.5330
# Horizon overall: mae: 5.5604, mape: 0.4621, rmse: 13.5330
# Horizon overall: mae: 5.5604, mape: 0.4621, rmse: 13.5330
# INFO:__main__:Horizon overall: mae: 5.5604, mape: 0.4621, rmse: 13.5330
# Horizon 5mins: mae: 5.3129, mape: 0.4585, rmse: 12.2669
# Horizon 5mins: mae: 5.3129, mape: 0.4585, rmse: 12.2669
# Horizon 5mins: mae: 5.3129, mape: 0.4585, rmse: 12.2669
# INFO:__main__:Horizon 5mins: mae: 5.3129, mape: 0.4585, rmse: 12.2669
# Epoch [200/500] (600) train_loss: 4.0678, val_loss: 5.7529, lr: 0.000100, 2.1s
# Epoch [200/500] (600) train_loss: 4.0678, val_loss: 5.7529, lr: 0.000100, 2.1s
# Epoch [200/500] (600) train_loss: 4.0678, val_loss: 5.7529, lr: 0.000100, 2.1s
# INFO:__main__:Epoch [200/500] (600) train_loss: 4.0678, val_loss: 5.7529, lr: 0.000100, 2.1s
# Horizon overall: mae: 5.5568, mape: 0.4652, rmse: 13.5199
# Horizon overall: mae: 5.5568, mape: 0.4652, rmse: 13.5199
# Horizon overall: mae: 5.5568, mape: 0.4652, rmse: 13.5199
# INFO:__main__:Horizon overall: mae: 5.5568, mape: 0.4652, rmse: 13.5199
# Horizon 5mins: mae: 5.3139, mape: 0.4608, rmse: 12.2727
# Horizon 5mins: mae: 5.3139, mape: 0.4608, rmse: 12.2727
# Horizon 5mins: mae: 5.3139, mape: 0.4608, rmse: 12.2727
# INFO:__main__:Horizon 5mins: mae: 5.3139, mape: 0.4608, rmse: 12.2727
# ===================================Best model performance===================================
# ===================================Best model performance===================================
# ===================================Best model performance===================================
# INFO:__main__:===================================Best model performance===================================
# Horizon overall: mae: 5.5568, mape: 0.4652, rmse: 13.5199
# Horizon overall: mae: 5.5568, mape: 0.4652, rmse: 13.5199
# Horizon overall: mae: 5.5568, mape: 0.4652, rmse: 13.5199
# INFO:__main__:Horizon overall: mae: 5.5568, mape: 0.4652, rmse: 13.5199
# Horizon 5mins: mae: 5.3139, mape: 0.4608, rmse: 12.2727
# Horizon 5mins: mae: 5.3139, mape: 0.4608, rmse: 12.2727
# Horizon 5mins: mae: 5.3139, mape: 0.4608, rmse: 12.2727
# INFO:__main__:Horizon 5mins: mae: 5.3139, mape: 0.4608, rmse: 12.2727
# training and testing ended Thu Dec 21 18:07:54 2023
# training and testing ended Thu Dec 21 18:07:54 2023
# training and testing ended Thu Dec 21 18:07:54 2023
# INFO:__main__:training and testing ended Thu Dec 21 18:07:54 2023
# tensor([[[[  0.0000,   0.0000],
#           [  0.0000,   1.0000],
#           [  6.0000,  33.0000],
#           ...,
#           [138.0000, 267.0000],
#           [ 77.0000,  78.0000],
#           [ 34.0000,  19.0000]],
#
#          [[  0.0000,   2.0000],
#           [  0.0000,   0.0000],
#           [  1.0000,  14.0000],
#           ...,
#           [ 58.0000,  62.0000],
#           [ 37.0000,  29.0000],
#           [ 17.0000,  29.0000]],
#
#          [[  0.0000,   0.0000],
#           [  0.0000,   0.0000],
#           [  1.0000,   4.0000],
#           ...,
#           [  8.0000,  15.0000],
#           [  5.0000,   3.0000],
#           [  8.0000,   9.0000]]],
#
#
#         [[[  0.0000,   2.0000],
#           [  0.0000,   0.0000],
#           [  1.0000,  14.0000],
#           ...,
#           [ 58.0000,  62.0000],
#           [ 37.0000,  29.0000],
#           [ 17.0000,  29.0000]],
#
#          [[  0.0000,   0.0000],
#           [  0.0000,   0.0000],
#           [  1.0000,   4.0000],
#           ...,
#           [  8.0000,  15.0000],
#           [  5.0000,   3.0000],
#           [  8.0000,   9.0000]],
#
#          [[  0.0000,   0.0000],
#           [  0.0000,   0.0000],
#           [  1.0000,   1.0000],
#           ...,
#           [ 14.0000,   1.0000],
#           [ 14.0000,  12.0000],
#           [  6.0000,   2.0000]]],
#
#
#         [[[  0.0000,   0.0000],
#           [  0.0000,   0.0000],
#           [  1.0000,   4.0000],
#           ...,
#           [  8.0000,  15.0000],
#           [  5.0000,   3.0000],
#           [  8.0000,   9.0000]],
#
#          [[  0.0000,   0.0000],
#           [  0.0000,   0.0000],
#           [  1.0000,   1.0000],
#           ...,
#           [ 14.0000,   1.0000],
#           [ 14.0000,  12.0000],
#           [  6.0000,   2.0000]],
#
#          [[  0.0000,   5.0000],
#           [  2.0000,   1.0000],
#           [  9.0000,  12.0000],
#           ...,
#           [224.0000,  89.0000],
#           [ 49.0000,  59.0000],
#           [ 40.0000,   1.0000]]],
#
#
#         ...,
#
#
#         [[[  0.0000,   2.0000],
#           [  1.0000,   1.0000],
#           [  2.0000,   6.0000],
#           ...,
#           [180.0000, 162.0000],
#           [ 29.0000,  42.0000],
#           [ 76.0000,  16.0000]],
#
#          [[  0.0000,   5.0000],
#           [  0.0000,   1.0000],
#           [ 11.0000,  38.0000],
#           ...,
#           [252.0000, 231.0000],
#           [ 46.0000,  48.0000],
#           [ 78.0000,  14.0000]],
#
#          [[  1.0000,  11.0000],
#           [  1.0000,   2.0000],
#           [  7.0000,  52.0000],
#           ...,
#           [209.0000, 242.0000],
#           [ 58.0000,  70.0000],
#           [ 65.0000,  31.0000]]],
#
#
#         [[[  0.0000,   5.0000],
#           [  0.0000,   1.0000],
#           [ 11.0000,  38.0000],
#           ...,
#           [252.0000, 231.0000],
#           [ 46.0000,  48.0000],
#           [ 78.0000,  14.0000]],
#
#          [[  1.0000,  11.0000],
#           [  1.0000,   2.0000],
#           [  7.0000,  52.0000],
#           ...,
#           [209.0000, 242.0000],
#           [ 58.0000,  70.0000],
#           [ 65.0000,  31.0000]],
#
#          [[  0.0000,   1.0000],
#           [  0.0000,   2.0000],
#           [  4.0000,  39.0000],
#           ...,
#           [141.0000, 140.0000],
#           [ 30.0000,  36.0000],
#           [ 50.0000,  24.0000]]],
#
#
#         [[[  1.0000,  11.0000],
#           [  1.0000,   2.0000],
#           [  7.0000,  52.0000],
#           ...,
#           [209.0000, 242.0000],
#           [ 58.0000,  70.0000],
#           [ 65.0000,  31.0000]],
#
#          [[  0.0000,   1.0000],
#           [  0.0000,   2.0000],
#           [  4.0000,  39.0000],
#           ...,
#           [141.0000, 140.0000],
#           [ 30.0000,  36.0000],
#           [ 50.0000,  24.0000]],
#
#          [[  0.0000,   2.0000],
#           [  0.0000,   1.0000],
#           [  0.0000,  17.0000],
#           ...,
#           [ 54.0000,  46.0000],
#           [ 12.0000,   6.0000],
#           [ 27.0000,  13.0000]]]], device='cuda:0')
