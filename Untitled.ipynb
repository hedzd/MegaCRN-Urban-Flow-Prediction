# %%
import pandas as pd

# %%
df = pd.read_excel('estacoes-gira-1-trimestre-2023.xlsx')

# %%
df
# Out:
#                                            desigcomercial  numbicicletas
# 0       410 - Rua da Mesquita / Universidade Nova de L...             11  \
# 1          417 - Av. Duque de Ávila / Jardim Arco Do Cego              3
# 2              301 - Avenida da Liberdade / Restauradores              6
# 3       459 - Rua Maria Amália Vaz de Carvalho / ES Ra...             15
# 4                                     218 - Cais do Sodré              9
# ...                                                   ...            ...
# 933639    213 - Av. Infante Dom Henrique / Santa Apolónia             16
# 933640                  311 - Avenida Almirante Reis Nº14             10
# 933641                   403 - Av. Fontes Pereira de Melo              3
# 933642       416 - Av. República / Avenida Duque de Ávila              1
# 933643  490 - Rua Fernando Namora / Azinhaga da Torre ...              1
#
#         numdocas                                           position
# ...

# %%
df.loc[df.desigcomercial == '218 - Cais do Sodré']
# Out:
#              desigcomercial  numbicicletas  numdocas
# 4       218 - Cais do Sodré              9        22  \
# 38      218 - Cais do Sodré              6        22
# 113     218 - Cais do Sodré              7        22
# 191     218 - Cais do Sodré              9        22
# 250     218 - Cais do Sodré              9        22
# ...                     ...            ...       ...
# 933160  218 - Cais do Sodré              7        22
# 933265  218 - Cais do Sodré              7        22
# 933354  218 - Cais do Sodré              1        22
# 933453  218 - Cais do Sodré              6        22
# 933475  218 - Cais do Sodré              4        22
#
#                                                  position
# 4       {"coordinates":[-9.14471,38.70617],"type":"Poi...  \
# 38      {"coordinates":[-9.14471,38.70617],"type":"Poi...
# 113     {"coordinates":[-9.14471,38.70617],"type":"Poi...
# 191     {"coordinates":[-9.14471,38.70617],"type":"Poi...
# ...

# %%
df2 = pd.read_csv('Gira - Bicicletas de Lisboa 2021.csv')

# %%
df2
# Out:
#                                             desigcomercial  numbicicletas
# 0           112 - Alameda dos Oceanos / Passeio das Garças              6  \
# 1                                  222 - Praça da Figueira             20
# 2           430 - Av. Barbosa Du Bocage / Rua Arco do Cego              1
# 3               456 - Entrecampos / Av. das Forças Armadas              8
# 4              415 - Av. Duque de Ávila / Av. Conde Valbom              2
# ...                                                    ...            ...
# 2218601  115 - Passeio dos Heróis do Mar / Rua Capitão ...              7
# 2218602                      468 - Largo Frei Heitor Pinto              6
# 2218603                 463 - Campo Grande / Av. da Igreja              5
# 2218604                  487 - Rua Professor João Barreira              5
# 2218605  133 - Rua Cidade de Benguela / Avenida Cidade ...              4
#
#          numdocas  numdocasvacias
# 0              14               8  \
# ...

# %%
df2.loc[df2.desigcomercial == '487 - Rua Professor João Barreira']
# Out:
#                             desigcomercial  numbicicletas  numdocas
# 40       487 - Rua Professor João Barreira             12        14  \
# 96       487 - Rua Professor João Barreira             10        14
# 163      487 - Rua Professor João Barreira              8        14
# 175      487 - Rua Professor João Barreira              8        14
# 364      487 - Rua Professor João Barreira              7        14
# ...                                    ...            ...       ...
# 2218125  487 - Rua Professor João Barreira              9        14
# 2218348  487 - Rua Professor João Barreira             11        14
# 2218527  487 - Rua Professor João Barreira              7        14
# 2218564  487 - Rua Professor João Barreira              5        14
# 2218604  487 - Rua Professor João Barreira              5        14
#
#          numdocasvacias                                           position
# ...
